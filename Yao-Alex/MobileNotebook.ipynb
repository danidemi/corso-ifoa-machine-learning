# %%
import pandas as pd

# %%
mobiles = pd.read_xlsx("/Users/test/corso-ifoa-machine-learning/Yao-Alex/mobile copia.xltx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-b590e52b91e0> in <module>
# ----> 1 mobiles = pd.read_xlsx("/Users/test/corso-ifoa-machine-learning/Yao-Alex/mobile copia.xltx")
#
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
# Out:
#       Unnamed: 0                                               name  \
# 0              0  Mione K1 ROM 3GB RAM 32GB 5.99 Inch display 4G...
# 1              1  Porsche design Huawei Mate 20 RS Dual SIM - 512GB
# 2              2               Samsung Galaxy Fold Dual SIM - 512GB
# 3              3               Samsung Galaxy Fold Dual SIM - 512GB
# 4              4             Blackberry P'9981 Porsche Design - 8GB
# ...          ...                                                ...
# 2755        2755        Huawei P40 Pro Single SIM and E-SIM - 256GB
# 2756        2756           Apple iPhone XR without Face Time - 64GB
# 2757        2757             Samsung Galaxy S10 Plus Dual Sim - 1Tb
# 2758        2758              Apple iPhone 11 with FaceTime - 256GB
# 2759        2759           Samsung Galaxy S20 Plus Dual SIM - 128GB
#
#                Generation          Color       Number_Of_SIM      item_price  \
# ...

# %%
Color = mobiles["Color"]
Color
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# <ipython-input-4-a48a36cfa617> in <module>
# ----> 1 Color = mobiles["Color"]
#       2 Color
#
# NameError: name 'mobiles' is not defined
