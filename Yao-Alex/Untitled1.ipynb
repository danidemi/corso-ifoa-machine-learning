# %%
import pandas as pd
import numpy as np

# %%
sp = pd.read_excel("/Volumes/SG SSD/mobile copia.xlsx")
sp
# Out:
#         id                                               name    Generation  \
# 0        0  Mione K1 ROM 3GB RAM 32GB 5.99 Inch display 4G...            4G
# 1        1  Porsche design Huawei Mate 20 RS Dual SIM - 512GB        4G LTE
# 2        2               Samsung Galaxy Fold Dual SIM - 512GB        4G LTE
# 3        3               Samsung Galaxy Fold Dual SIM - 512GB        4G LTE
# 4        4             Blackberry P'9981 Porsche Design - 8GB  2G/3G/4G LTE
# ...    ...                                                ...           ...
# 2747  2751              Apple iPhone 11 with FaceTime - 256GB        4G LTE
# 2748  2752           Samsung Galaxy S20 Plus Dual SIM - 128GB            5G
# 2749  2753           Samsung Galaxy S20 Plus Dual SIM - 128GB            5G
# 2750  2754           Samsung Galaxy S20 Plus Dual SIM - 128GB           5G
# 2751  2755             Apple Iphone XR With Face Time - 64 GB        4G LTE
#
#        Color       Number_Of_SIM      item_price item_brand_name Unnamed: 7
# 0      Black                 NaN  227,599.00 SAR           mione        NaN
# 1        Red                 NaN    8,500.00 SAR          huawei        NaN
# 2     Silver                 NaN    7,587.00 SAR         samsung        NaN
# 3      Black                 NaN    7,099.00 SAR         samsung        NaN
# 4      Black                 NaN    6,550.00 SAR      blackberry        NaN
# ...      ...                 ...             ...             ...        ...
# 2747   Black  Single SIM & E-SIM    3,650.99 SAR           apple        NaN
# 2748   Black                 NaN    3,624.98 SAR         samsung        NaN
# 2749    Grey                 NaN    3,617.97 SAR         samsung        NaN
# 2750    Blue                 NaN    3,617.97 SAR         samsung        NaN
# 2751   White  Single Sim & E-Sim    3,599.00 SAR           apple        NaN
#
# [2752 rows x 8 columns]

# %%
sp[0:10]
# Out:
#    id                                               name    Generation  \
# 0   0  Mione K1 ROM 3GB RAM 32GB 5.99 Inch display 4G...            4G
# 1   1  Porsche design Huawei Mate 20 RS Dual SIM - 512GB        4G LTE
# 2   2               Samsung Galaxy Fold Dual SIM - 512GB        4G LTE
# 3   3               Samsung Galaxy Fold Dual SIM - 512GB        4G LTE
# 4   4             Blackberry P'9981 Porsche Design - 8GB  2G/3G/4G LTE
# 5   5      Apple iPhone 11 Pro Max with FaceTime - 512GB        4G LTE
# 6   6      Apple iPhone 11 Pro Max with FaceTime - 512GB        4G LTE
# 7   7         Apple Iphone XS Max With Facetime - 512 GB        4G LTE
# 8   8         Apple Iphone XS Max With Facetime - 512 GB        4G LTE
# 9  10      Huawei Mate 9 Porsche Design Dual Sim - 256GB        4G LTE
#
#     Color       Number_Of_SIM      item_price item_brand_name Unnamed: 7
# 0   Black                 NaN  227,599.00 SAR           mione        NaN
# 1     Red                 NaN    8,500.00 SAR          huawei        NaN
# 2  Silver                 NaN    7,587.00 SAR         samsung        NaN
# 3   Black                 NaN    7,099.00 SAR         samsung        NaN
# 4   Black                 NaN    6,550.00 SAR      blackberry        NaN
# 5   green  Single SIM & E-SIM    6,163.49 SAR           apple        NaN
# 6  Silver  Single SIM & E-SIM    6,098.98 SAR           apple        NaN
# 7  Silver  Single Sim & E-Sim    5,999.00 SAR           apple        NaN
# 8    Grey  Single Sim & E-Sim    5,999.00 SAR           apple        NaN
# 9   Black                 NaN    5,900.00 SAR          huawei        NaN

# %%
sp['Color']
# Out:
# 0        Black
# 1          Red
# 2       Silver
# 3        Black
# 4        Black
#          ...
# 2747     Black
# 2748     Black
# 2749      Grey
# 2750      Blue
# 2751     White
# Name: Color, Length: 2752, dtype: object

# %%
sp[sp.Color == "Black"]
# Out:
#         id                                               name    Generation  \
# 0        0  Mione K1 ROM 3GB RAM 32GB 5.99 Inch display 4G...            4G
# 3        3               Samsung Galaxy Fold Dual SIM - 512GB        4G LTE
# 4        4             Blackberry P'9981 Porsche Design - 8GB  2G/3G/4G LTE
# 9       10      Huawei Mate 9 Porsche Design Dual Sim - 256GB        4G LTE
# 23      24     Huawei Mate RS Porsche Design Dual SIM - 256GB        4G LTE
# ...    ...                                                ...           ...
# 2734  2738               Thuraya XT -Pro with Prepay SIM Card            2G
# 2735  2739                                   Cat S61 Dual Sim            4G
# 2740  2744                     Sony Xperia 1 Dual SIM - 128GB        4G LTE
# 2747  2751              Apple iPhone 11 with FaceTime - 256GB        4G LTE
# 2748  2752           Samsung Galaxy S20 Plus Dual SIM - 128GB            5G
#
#       Color       Number_Of_SIM      item_price item_brand_name Unnamed: 7
# 0     Black                 NaN  227,599.00 SAR           mione        NaN
# 3     Black                 NaN    7,099.00 SAR         samsung        NaN
# 4     Black                 NaN    6,550.00 SAR      blackberry        NaN
# 9     Black                 NaN    5,900.00 SAR          huawei        NaN
# 23    Black                 NaN    4,999.00 SAR          huawei        NaN
# ...     ...                 ...             ...             ...        ...
# 2734  Black                 NaN    4,280.00 SAR         thuraya        NaN
# 2735  Black                 NaN    4,200.00 SAR             cat        NaN
# 2740  Black                 NaN    3,699.00 SAR            sony        NaN
# 2747  Black  Single SIM & E-SIM    3,650.99 SAR           apple        NaN
# 2748  Black                 NaN    3,624.98 SAR         samsung        NaN
#
# [672 rows x 8 columns]

# %% [markdown]
# df[(df.name == 'apple' ) & (df.name == 'samsung') & (df.Color == 'black')]

# %%
sp[(sp.item_brand_name == "apple") & (sp.Color == 'Black')]
# Out:
#         id                                       name Generation  Color  \
# 44      45      Apple iPhone 11 with FaceTime - 256GB     4G LTE  Black
# 51      52  Apple iPhone 7 Plus with FaceTime - 128GB     4G LTE  Black
# 103    105      Apple iPhone 11 with FaceTime - 256GB     4G LTE  Black
# 110    112  Apple iPhone 7 Plus with FaceTime - 128GB     4G LTE  Black
# 162    165      Apple iPhone 11 with FaceTime - 256GB     4G LTE  Black
# ...    ...                                        ...        ...    ...
# 2629  2633      Apple iPhone 11 with FaceTime - 256GB     4G LTE  Black
# 2636  2640  Apple iPhone 7 Plus with FaceTime - 128GB     4G LTE  Black
# 2688  2692      Apple iPhone 11 with FaceTime - 256GB     4G LTE  Black
# 2695  2699  Apple iPhone 7 Plus with FaceTime - 128GB     4G LTE  Black
# 2747  2751      Apple iPhone 11 with FaceTime - 256GB     4G LTE  Black
#
#            Number_Of_SIM    item_price item_brand_name Unnamed: 7
# 44    Single SIM & E-SIM  3,650.99 SAR           apple        NaN
# 51                   NaN  3,499.00 SAR           apple        NaN
# 103   Single SIM & E-SIM  3,650.99 SAR           apple        NaN
# 110                  NaN  3,499.00 SAR           apple        NaN
# 162   Single SIM & E-SIM  3,650.99 SAR           apple        NaN
# ...                  ...           ...             ...        ...
# 2629  Single SIM & E-SIM  3,650.99 SAR           apple        NaN
# 2636                 NaN  3,499.00 SAR           apple        NaN
# 2688  Single SIM & E-SIM  3,650.99 SAR           apple        NaN
# 2695                 NaN  3,499.00 SAR           apple        NaN
# 2747  Single SIM & E-SIM  3,650.99 SAR           apple        NaN
#
# [88 rows x 8 columns]

# %%
sp['Color'].head()
# Out:
# 0     Black
# 1       Red
# 2    Silver
# 3     Black
# 4     Black
# Name: Color, dtype: object
