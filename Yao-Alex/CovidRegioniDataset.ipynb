# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
cr = pd.read_csv("/Users/test/Downloads/covid19_italy_region.csv")
cr
# Out:
#        SNo                 Date Country  RegionCode      RegionName  \
# 0        0  2020-02-24T18:00:00     ITA          13         Abruzzo
# 1        1  2020-02-24T18:00:00     ITA          17      Basilicata
# 2        2  2020-02-24T18:00:00     ITA          18        Calabria
# 3        3  2020-02-24T18:00:00     ITA          15        Campania
# 4        4  2020-02-24T18:00:00     ITA           8  Emilia-Romagna
# ...    ...                  ...     ...         ...             ...
# 4237  4237  2020-09-12T17:00:00     ITA          19         Sicilia
# 4238  4238  2020-09-12T17:00:00     ITA           9         Toscana
# 4239  4239  2020-09-12T17:00:00     ITA          10          Umbria
# 4240  4240  2020-09-12T17:00:00     ITA           2   Valle d'Aosta
# 4241  4241  2020-09-12T17:00:00     ITA           5          Veneto
#
#        Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0     42.351222  13.398438                     0                      0
# ...

# %%
cr[0:10]
# Out:
#    SNo                 Date Country  RegionCode             RegionName  \
# 0    0  2020-02-24T18:00:00     ITA          13                Abruzzo
# 1    1  2020-02-24T18:00:00     ITA          17             Basilicata
# 2    2  2020-02-24T18:00:00     ITA          18               Calabria
# 3    3  2020-02-24T18:00:00     ITA          15               Campania
# 4    4  2020-02-24T18:00:00     ITA           8         Emilia-Romagna
# 5    5  2020-02-24T18:00:00     ITA           6  Friuli Venezia Giulia
# 6    6  2020-02-24T18:00:00     ITA          12                  Lazio
# 7    7  2020-02-24T18:00:00     ITA           7                Liguria
# 8    8  2020-02-24T18:00:00     ITA           3              Lombardia
# 9    9  2020-02-24T18:00:00     ITA          11                 Marche
#
#     Latitude  Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  42.351222  13.398438                     0                      0
# ...

# %%
Morti = cr["Deaths"]
Morti
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 4237     289
# 4238    1148
# 4239      81
# 4240     146
# 4241    2141
# Name: Deaths, Length: 4242, dtype: int64

# %%
Data = cr["Date"]
Data
# Out:
# 0       2020-02-24T18:00:00
# 1       2020-02-24T18:00:00
# 2       2020-02-24T18:00:00
# 3       2020-02-24T18:00:00
# 4       2020-02-24T18:00:00
#                ...
# 4237    2020-09-12T17:00:00
# 4238    2020-09-12T17:00:00
# 4239    2020-09-12T17:00:00
# 4240    2020-09-12T17:00:00
# 4241    2020-09-12T17:00:00
# Name: Date, Length: 4242, dtype: object

# %%
Regioni = cr["RegionName"]
Regioni
# Out:
# 0              Abruzzo
# 1           Basilicata
# 2             Calabria
# 3             Campania
# 4       Emilia-Romagna
#              ...
# 4237           Sicilia
# 4238           Toscana
# 4239            Umbria
# 4240     Valle d'Aosta
# 4241            Veneto
# Name: RegionName, Length: 4242, dtype: object

# %%
POspit = cr["HospitalizedPatients"]
POspit
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4        10
#        ...
# 4237    116
# 4238     74
# 4239     18
# 4240      3
# 4241     99
# Name: HospitalizedPatients, Length: 4242, dtype: int64

# %%
PTerapIntens = cr["IntensiveCarePatients"]

# %%
PConfiCasa = cr["HomeConfinement"]

# %%
CasiPositivi = cr["CurrentPositiveCases"]

# %%
Ricoveri = cr["Recovered"]

# %%
TestEffettuati = cr["TestsPerformed"]

# %%
cr['RegionName'].unique()
# Out:
# array(['Abruzzo', 'Basilicata', 'Calabria', 'Campania', 'Emilia-Romagna',
#        'Friuli Venezia Giulia', 'Lazio', 'Liguria', 'Lombardia', 'Marche',
#        'Molise', 'P.A. Bolzano', 'P.A. Trento', 'Piemonte', 'Puglia',
#        'Sardegna', 'Sicilia', 'Toscana', 'Umbria', "Valle d'Aosta",
#        'Veneto'], dtype=object)

# %%
cr[cr.RegionName == "Lombardia"]
# Out:
#        SNo                 Date Country  RegionCode RegionName   Latitude  \
# 8        8  2020-02-24T18:00:00     ITA           3  Lombardia  45.466794
# 29      29  2020-02-25T18:00:00     ITA           3  Lombardia  45.466794
# 50      50  2020-02-26T18:00:00     ITA           3  Lombardia  45.466794
# 71      71  2020-02-27T18:00:00     ITA           3  Lombardia  45.466794
# 92      92  2020-02-28T18:00:00     ITA           3  Lombardia  45.466794
# ...    ...                  ...     ...         ...        ...        ...
# 4145  4145  2020-09-08T17:00:00     ITA           3  Lombardia  45.466794
# 4166  4166  2020-09-09T17:00:00     ITA           3  Lombardia  45.466794
# 4187  4187  2020-09-10T17:00:00     ITA           3  Lombardia  45.466794
# 4208  4208  2020-09-11T17:00:00     ITA           3  Lombardia  45.466794
# 4229  4229  2020-09-12T17:00:00     ITA           3  Lombardia  45.466794
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# ...

# %% [raw]
# cr[(cr.RegionName == 'Lombardia') & (CR.Deaths)]

# %%
cr[(Regioni == "Lombardia")]["Deaths"]
# Out:
# 8           6
# 29          9
# 50          9
# 71         14
# 92         17
#         ...
# 4145    16888
# 4166    16891
# 4187    16892
# 4208    16896
# 4229    16896
# Name: Deaths, Length: 202, dtype: int64

# %%
Morti.describe()
# Out:
# count     4242.000000
# mean      1265.888496
# std       3075.511105
# min          0.000000
# 25%         76.000000
# 50%        292.000000
# 75%        965.500000
# max      16896.000000
# Name: Deaths, dtype: float64
