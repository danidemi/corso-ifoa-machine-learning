# %% [markdown]
# Tutorial Project Work
# =================

# %% [markdown]
# ## Dataset Scarpe da Donna

# %%
# I dataset sono forniti in .zip, il codice sottostante permette di unzippare i file 
# per ottenre i .csv contenuti.

import zipfile
import os

def print_file_list():
    for root, dirs, files in os.walk("dataset"):
       for name in files:
          print(os.path.join(root, name))
            
def unzip(dataset):
    zip_path = os.path.join("dataset", dataset)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall("dataset")

print_file_list()        
print("unzipping woman shoes")                
unzip('woman-shoes.zip')
print_file_list()
# Out:
# dataset\.gitignore
# dataset\7210_1.csv
# dataset\Datafiniti_Mens_Shoe_Prices.csv
# dataset\Datafiniti_Womens_Shoes.csv
# dataset\Datafiniti_Womens_Shoes_Jun19.csv
# dataset\info.md
# dataset\man-shoes.zip
# dataset\woman-shoes.zip
# unzipping woman shoes
# dataset\.gitignore
# dataset\7210_1.csv
# dataset\Datafiniti_Mens_Shoe_Prices.csv
# dataset\Datafiniti_Womens_Shoes.csv
# dataset\Datafiniti_Womens_Shoes_Jun19.csv
# dataset\info.md
# dataset\man-shoes.zip
# dataset\woman-shoes.zip

# %%
# Caricare i dataset in un dataframe
import pandas as pd
import os

dataset = pd.read_csv( os.path.join("dataset", "Datafiniti_Womens_Shoes.csv") )

# %%
# Quali colonne esistono? Esempio di una riga...

cols = list(dataset.columns)
row = dataset.iloc[12]
for col in cols:
    print("col [" + col + "]: " + str( row[col] ))
    print()
# Out:
# col [id]: AVph9abqilAPnD_x_Nrp
#
# col [dateAdded]: 2017-01-07T20:51:09Z
#
# col [dateUpdated]: 2018-01-04T11:52:59Z
#
# col [asins]: nan
#
# col [brand]: MUK LUKS
#
# col [categories]: Clothing,Shoes,Women's Shoes,All Women's Shoes,Women's Boots
#
# col [primaryCategories]: Shoes
#
# col [colors]: Grey,Dark Brown,Chestnut,Brown
#
# col [dimension]: 6.0 in x 6.0 in x 1.0 in
#
# col [ean]: 33977133976.0
#
# col [imageURLs]: https://i5.walmartimages.com/asr/2bdab33e-79ec-4aa2-8f59-f3a807401879_1.eb22913d7c5e0857964bc8375993395b.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/abcd3e2c-e974-46d0-908e-6459896d1930_1.7c87021539ad1923e4bbdfc57cbd4f73.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/178fde13-ed79-4920-ab62-2d048b291e88_1.69dc6eabaf3dc53a10cdcb62c2dec1d7.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/332d77a4-50ff-4ae8-b9c1-9cc2dd6b79bd_1.6b205823d6c1f6e356a4ed73923cdf6b.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF,https://i5.walmartimages.com/asr/72a12ac8-4dce-411b-898a-28293d250d7c_1.ac01136f37f9c0427e3651d7d9fd760a.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF
#
# col [keys]: 033977133976,muklukswomensdemiboot/554234398,reliableofmilwuakee/0003397713397,0033977133976,mukluks/0003397713397
#
# col [manufacturer]: Reliable of Milwuakee
#
# col [manufacturerNumber]: 3397713397
#
# col [name]: MUK LUKS Women's Demi Boot
#
# col [prices.amountMax]: 68.0
#
# col [prices.amountMin]: 41.27
#
# col [prices.availability]: Out Of Stock
#
# col [prices.color]: Dark Brown
#
# col [prices.condition]: New
#
# col [prices.currency]: USD
#
# col [prices.dateAdded]: 2017-11-22T19:36:35Z
#
# col [prices.dateSeen]: 2017-11-01T02:49:00.000Z
#
# col [prices.isSale]: True
#
# col [prices.merchant]: Walmart.com
#
# col [prices.offer]: nan
#
# col [prices.returnPolicy]: nan
#
# col [prices.shipping]: nan
#
# col [prices.size]: 6
#
# col [prices.sourceURLs]: https://www.walmart.com/ip/MUK-LUKS-Women-s-Demi-Boot/45801178
#
# col [sizes]: 10,7,6,9,8
#
# col [sourceURLs]: https://www.walmart.com/ip/MUK-LUKS-Women-s-Demi-Boot/45801178,https://www.walmart.com/reviews/product/45801178
#
# col [upc]: 033977133976
#
# col [weight]: nan

# %%
dataset["brand"].unique()
# Out:
# array(['Naturalizer', 'MUK LUKS', 'Soft Ones', 'muk luks', 'Sloggers',
#        "Dr. Scholl's", 'Genuine Dickies', 'Mo Mo', 'SKECHERS',
#        'lc lauren conrad', 'FOREVER YOUNG', 'Unbranded', 'Faded Glory',
#        'qupid', 'olivia miller', 'Victoria K.', 'Keds', 'herstar',
#        'Earth Spirit', 'Unique Bargains', 'lifestride',
#        'naturalsoul by naturalizer', 'Lugz', 'lugz',
#        'style charles by charles david', 'nyla', 'Daniel Green', 'corkys',
#        'IB Non-Slip', 'Silver Lilly', 'ELLIE SHOES', 'SoftWalk',
#        'Brinley Co.', 'MLB', 'easy street', 'Danskin Now',
#        'forever collectibles', 'Carrini', 'Riverberry',
#        'journee collection', 'eastland', 'so', 'dolce by mojo moxy',
#        'under armour', 'koolaburra by ugg', 'skechers', 'puma', 'adidas',
#        'new balance', 'rampage', 'vans', 'croft barrow', 'candies',
#        'simply vera vera wang', 'apt. 9', 'jennifer lopez',
#        'sonoma goods for life', 'soft style by hush puppies', 'keds',
#        'Laredo', 'rocky 4eursole', 'ryka', 'dr. scholls', 'Ryka',
#        'Lifestride', 'Fergalicious', 'fila', 'a2 by aerosoles',
#        'henry ferrera', 'andrew geller', 'nike', 'spring step', 'seven7',
#        'Brinley Co. Collection', 'madden nyc', 'Easy Street', 'Nike',
#        'betula by birkenstock', 'kisses by 2 lips too', '2 lips too',
#        'reef', 'unionbay', 'k-swiss', 'sugar', 'clarks', 'asics',
#        'La Sportiva', "Arc'teryx", 'Topo Athletic', 'Chaco', 'Scarpa',
#        'Soludos', 'New Balance', 'Birkenstock', 'Splendid',
#        'Native Shoes', 'Brooks', 'Merrell', 'Salomon', 'Asics', 'Saucony',
#        'Red Wing', 'Altra', 'Adidas', 'Frye', 'Under Armour',
#        'Adidas Outdoor', 'SeaVees', 'Seychelles Footwear',
#        'The North Face', 'On Footwear', 'Hoka One One', 'Mammut',
#        'Inov 8', 'Salewa', 'Toms', 'Vans', 'UGG', 'Astral', 'Timberland',
#        'Olukai', 'KEEN', 'Dansko', 'Free People', 'Sperry Top-Sider',
#        'Bogs', 'Lowa', 'Kaanas', 'OTZShoes'], dtype=object)

# %%
dataset["categories"].unique()
# Out:
# array(["Clothing,Shoes,Women's Shoes,All Women's Shoes,Heels,Sandals",
#        "Clothing,Shoes,Women's Shoes,Women's Casual Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Women's Slippers",
#        "Womens Shoes,Clothing,Women's Shoes,Baby & Kids Shoes,Baby & Toddler Shoes,All Womens Shoes,Shoes,All Women's Shoes",
#        "MUK LUKS,Womens,Women's Casual Shoes,Clothing,Women's Shoes,Women's Slippers,Slippers,Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,Women's Winter Boots,All Women's Shoes,Women's Boots",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Women's Boots",
#        "Womens,Shoes,Sandals,MUK LUKS,Clothing,Women's Shoes,All Women's Shoes",
#        "Womens Shoes,Clothing,Women's Shoes,All Womens Shoes,Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,Women's Dress Shoes,All Women's Shoes,Home Improvement,Work Safety Clothing and Equipment",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Women's Casual Shoes,Women's Slippers",
#        "Womens,Sneakers,Womens Casual Shoes,Womens Shoes,Clothing,Women's Shoes,Shoes,Athletic Shoes,Skechers,All Women's Shoes",
#        "Sneakers,Womens Shoes,Clothing,Work Safety Clothing and Equipment,Shoes,Skechers,All Women's Shoes,Womens,Women's Shoes,Home Improvement,All Womens Shoes,Athletic Shoes,Women's Work & Safety Shoes",
#        "Womens,Womens Shoes,Clothing,Women's Shoes,All Womens Shoes,Shoes,Sandals,Skechers,All Women's Shoes",
#        "Womens,Clothing,Women's Shoes,Boots,Shoes,Skechers,All Women's Shoes",
#        "Sneakers,Women's Athletic Shoes,Womens Shoes,Clothing,Shoes,Skechers,All Women's Shoes,Womens,Women's Casual Shoes,Womens Casual Shoes,Women's Shoes,All Womens Shoes,Athletic Shoes",
#        "Womens,Women's Casual Shoes,Sneakers,Womens Casual Shoes,Womens Shoes,Clothing,Women's Shoes,Shoes,Athletic Shoes,Skechers",
#        'Womens,Shoes,Boots,LC Lauren Conrad',
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Home Improvement,Work Safety Clothing and Equipment",
#        "Women's Casual Shoes,Womens Casual Shoes,Womens Shoes,Clothing,Women's Shoes,Shoes,All Women's Shoes",
#        "Clothing,Shoes,Womens Shoes,Womens Casual Shoes,Women's Shoes,Women's Casual Shoes,All Women's Shoes",
#        'Womens,Shoes,Sandals,Qupid', 'Womens,Shoes,Boots,Qupid',
#        'Womens,Shoes,Boots,Olivia Miller',
#        "Clothing,Shoes,Women's Shoes,Women's Casual Shoes,Womens,Boat Shoes,Keds",
#        'Womens,Shoes,Pumps,Heels,Herstar',
#        'Womens,Shoes,Boots,LifeStride',
#        'Womens,Shoes,Sandals,NaturalSoul by naturalizer',
#        "Womens,Womens Shoes,Clothing,Women's Shoes,Boys' Shoes,Boots,Lugz,All Womens Shoes,Shoes,All Women's Shoes",
#        'Womens,Shoes,Boots,Lugz',
#        'Womens,Shoes,Pumps,Heels,Style Charles by Charles David',
#        'Womens,Shoes,Sandals,Style Charles by Charles David',
#        'Womens,Shoes,Pumps,Heels,NYLA', 'Womens,Shoes,Pumps,Heels,Corkys',
#        "Clothing,Shoes,Womens Shoes,Womens Oxford & Loafers,Womens Oxfords,Women's Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Boots,Mid-Calf Boots",
#        "Clothing,Shoes,Womens Shoes,Womens Comfort,Womens Comfort Boots & Booties,Women's Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Women's Dress Shoes",
#        "Clothing,Shoes,Women's Shoes,Women's Dress Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,Women's Dress Shoes,All Women's Shoes,Women's Wear to Work,Women",
#        "Clothing,Shoes,Baby & Kids Shoes,Girls' Boots,Women's Shoes,All Women's Shoes,Girls' Shoes",
#        "Clothing,Shoes,Men's Shoes,All Men's Shoes,Women's Slippers,Women's Shoes,All Women's Shoes",
#        'Womens,Shoes,Oxfords,Easy Street',
#        'Womens,Shoes,Flats,Forever Collectibles',
#        "Clothing,Shoes,Women's Shoes,Women's Sandals,Women's Dress Shoes,All Women's Shoes",
#        'Womens,Shoes,Pumps,Heels,LifeStride',
#        'Womens,Shoes,Boots,Journee Collection',
#        'Womens,Shoes,Pumps,Heels,Journee Collection',
#        "Womens,Shoes,Pumps,Heels,Journee Collection,Clothing,Women's Shoes,All Women's Shoes,Women's Boots",
#        'Womens,Shoes,Sandals,LifeStride', 'Womens,Shoes,Loafers,Eastland',
#        "Womens,Shoes,Boat Shoes,Eastland,All Men's Shoes,Men's Shoes,Clothing",
#        "Womens,Shoes,Clogs,Mules,Eastland,Women's Casual Shoes,Women's Shoes,Clothing",
#        'Womens,Shoes,Boots,Eastland',
#        "Womens,Shoes,Clogs,Mules,Eastland,Women's Casual Shoes,Clothing,Women's Shoes",
#        'Womens,Shoes,Slippers',
#        'Womens,Shoes,Clogs,Mules,Dolce by Mojo Moxy',
#        'Womens,Shoes,Athletic Shoes,Sneakers,Under Armour',
#        'Womens,Shoes,Boots', 'Womens,Shoes,Flats', 'Shoes,Boots,Womens',
#        'Shoes,Boots,Koolaburra by UGG,Womens',
#        "Womens,Shoes,Athletic Shoes,Sneakers,Skechers,Slip-ons,Women's Shoes,Clothing,All Women's Shoes",
#        'Womens,Shoes,Athletic Shoes,Sneakers,Skechers',
#        'Womens,Shoes,Flats,Skechers',
#        'Womens,Shoes,Athletic Shoes,Sneakers,PUMA',
#        "Womens,Shoes,Athletic Shoes,Sneakers,adidas,Clothing, Shoes & Accessories,Women's Shoes,Athletic",
#        'Womens,Shoes,Athletic Shoes,Sneakers,adidas',
#        'Womens,Shoes,Athletic Shoes,Sneakers,New Balance',
#        "Womens,Shoes,Athletic Shoes,Sneakers,Skechers,Clothing,Women's Shoes,Women's Casual Shoes",
#        "Womens,Shoes,Athletic Shoes,Sneakers,Skechers,Clothing,Women's Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Womens,Athletic Shoes,Sneakers,Skechers",
#        "Womens,Shoes,Athletic Shoes,Sneakers,Skechers,Clothing,Women's Shoes,Women's Athletic Shoes",
#        'Womens,Rampage', 'Womens,Shoes,Athletic Shoes,Sneakers,Vans',
#        'Womens,Shoes,Flats,Croft,Barrow', "Womens,Shoes,Flats,Candie's",
#        'Womens,Shoes,Flats,Simply Vera Vera Wang',
#        'Womens,Shoes,Pumps,Heels,Croft,Barrow',
#        "Womens,Shoes,Boots,Candie's", 'Womens,Shoes,Sandals,Apt. 9',
#        'Womens,Shoes,Clogs,Mules,Croft,Barrow',
#        'Womens,Shoes,Athletic Shoes,Sneakers,Jennifer Lopez',
#        'Womens,Shoes,Boots,Simply Vera Vera Wang',
#        'Womens,Shoes,Boat Shoes,Croft,Barrow',
#        "Womens,Shoes,Pumps,Heels,Candie's",
#        'Womens,Shoes,Pumps,Heels,LC Lauren Conrad',
#        'Womens,Shoes,Flats,Jennifer Lopez',
#        'Womens,Shoes,Boots,Croft,Barrow',
#        'Womens,Shoes,Loafers,Journee Collection',
#        'Womens,Shoes,Boots,SONOMA Goods for Life',
#        'Womens,Shoes,Loafers,SONOMA Goods for Life',
#        'Womens,Shoes,Pumps,Heels,Simply Vera Vera Wang',
#        "Womens,Shoes,Sandals,LC Lauren Conrad,Clothing, Shoes & Accessories,Women's Shoes,Sandals & Flip Flops",
#        'Womens,Shoes,Sandals,Croft,Barrow',
#        'Womens,Shoes,Flats,LC Lauren Conrad',
#        'Womens,Shoes,Sandals,SONOMA Goods for Life,Boots',
#        'Womens,Shoes,Athletic Shoes,Sneakers,Croft,Barrow',
#        'Womens,Shoes,Sandals,SONOMA Goods for Life',
#        'Womens,Shoes,Pumps,Heels,Apt. 9',
#        'Womens,Shoes,Clogs,Mules,Soft Style by Hush Puppies',
#        'Womens,Shoes,Boots,Apt. 9',
#        'Womens,Shoes,Athletic Shoes,Sneakers,Keds',
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Womens Shoes,Shop by Clothing Type,Boots,Cowboy Boots,Womens,Laredo,Women's Boots",
#        'Womens,Shoes,Flats,Apt. 9', 'Womens,Shoes,Sandals,Rocky 4EurSole',
#        'Womens,Shoes,Flats,NaturalSoul by naturalizer',
#        'Womens,Shoes,Athletic Shoes,Sneakers,Ryka',
#        "Womens,Shoes,Pumps,Heels,LifeStride,Clothing,Women's Shoes,Women's Dress Shoes",
#        "Womens,Shoes,Boots,Dr. Scholl's,Women's Shoes,Clothing,All Women's Shoes",
#        'Womens,Shoes,Loafers,NaturalSoul by naturalizer',
#        'Womens,Shoes,Flats,LifeStride', 'Womens,Shoes,Loafers,LifeStride',
#        "Womens,Shoes,Flats,Dr. Scholl's", 'Womens,Shoes,Boots,Ryka',
#        "Womens,Shoes,Boots,Dr. Scholl's",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Womens,Athletic Shoes,Sneakers,Ryka",
#        "Womens,Shoes,Athletic Shoes,Sneakers,Dr. Scholl's,Clothing,Women's Shoes,All Women's Shoes",
#        "Womens,Shoes,Athletic Shoes,Sneakers,Ryka,Clothing,Women's Shoes,Women's Casual Shoes",
#        "Clothing,Shoes,Women's Shoes,Women's Dress Shoes,Womens,Sandals,LifeStride",
#        "Womens,Shoes,Sandals,Ryka,Clothing,Women's Shoes,All Women's Shoes",
#        "Womens,Shoes,Sandals,LifeStride,Clothing,Women's Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Womens,Sandals,LifeStride",
#        'Womens,Shoes,Pumps,Heels,NaturalSoul by naturalizer',
#        'Womens,Shoes,Sandals,Ryka',
#        'Womens,Shoes,Athletic Shoes,Sneakers,NaturalSoul by naturalizer',
#        "Womens,Shoes,Pumps,Heels,LifeStride,Clothing,Women's Shoes,Women's Dress Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,Women's Dress Shoes,Womens,Oxfords,Fergalicious",
#        "Womens,Shoes,Athletic Shoes,Sneakers,FILA,Women's Shoes,Clothing,All Women's Shoes",
#        'Womens,Shoes,Pumps,Heels,A2 by Aerosoles',
#        'Womens,Shoes,Boots,A2 by Aerosoles',
#        "Womens,Shoes,Pumps,Heels,A2 by Aerosoles,Women's Shoes,Flats,Comfort",
#        "Womens,Shoes,Sandals,A2 by Aerosoles,Clothing,Women's Shoes,All Women's Shoes",
#        'Womens,Shoes,Sandals,A2 by Aerosoles',
#        'Womens,Shoes,Loafers,A2 by Aerosoles',
#        'Womens,Shoes,Clogs,Mules,A2 by Aerosoles',
#        'Womens,Shoes,Flats,A2 by Aerosoles',
#        'Womens,Shoes,Clogs,Mules,Style Charles by Charles David',
#        'Womens,Shoes,Boots,Style Charles by Charles David',
#        'Womens,Shoes,Flats,Style Charles by Charles David',
#        'Womens,Shoes,Boots,Henry Ferrera',
#        "Womens,Shoes,Athletic Shoes,Sneakers,FILA,Clothing,Women's Shoes,All Women's Shoes",
#        'Womens,Shoes,Sandals,Soft Style by Hush Puppies',
#        'Womens,Shoes,Sandals,Andrew Geller',
#        'Womens,Shoes,Athletic Shoes,Sneakers,Nike',
#        "Womens,Shoes,Clogs,Mules,Spring Step,Clothing,Women's Shoes,All Women's Shoes",
#        "Womens,Shoes,Clogs,Mules,Spring Step,Clothing,Men's Shoes,Men's Casual Shoes,Other Slip-Ons",
#        'Womens,Shoes,Sandals,Spring Step',
#        "Womens,Shoes,Sandals,Spring Step,Clothing,Women's Shoes,All Women's Shoes,Low Slide Sandals",
#        'Womens,Shoes,Flats,Seven7', 'Womens,Shoes,Sandals,Seven7',
#        "Womens,Shoes,Boots,Journee Collection,Clothing,Women's Shoes,All Women's Shoes",
#        "Womens,Shoes,Pumps,Heels,Journee Collection,Clothing,Women's Shoes,Women's Dress Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,Women's Dress Shoes,Womens,Pumps,Heels,Journee Collection,All Women's Shoes",
#        'Womens,Shoes,Flats,Journee Collection',
#        "Womens,Shoes,Boots,Journee Collection,Clothing,Women's Shoes,Women's Boots,Heels",
#        'Womens,Shoes,Sandals,Journee Collection',
#        'Womens,Shoes,Clogs,Mules,Journee Collection',
#        'Womens,Shoes,Boots,madden NYC',
#        'Womens,Shoes,Pumps,Heels,madden NYC',
#        'Womens,Shoes,Sandals,madden NYC',
#        "Womens,Shoes,Athletic Shoes,Sneakers,Nike,Clothing,Women's Shoes,Women's Casual Shoes,Women's Athletic Shoes",
#        "Womens,Shoes,Athletic Shoes,Sneakers,Nike,Clothing,Women's Shoes,Women's Casual Shoes",
#        "Clothing,Shoes,Women's Shoes,Women's Dress Shoes,Womens,Pumps,Heels,Easy Street,All Women's Shoes",
#        "Womens,Shoes,Clogs,Mules,Easy Street,Women's Shoes,Clothing,All Women's Shoes",
#        'Womens,Shoes,Clogs,Mules,Easy Street',
#        "Womens,Shoes,Pumps,Heels,Easy Street,Clothing,Women's Shoes,All Women's Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Womens,Athletic Shoes,Sneakers,Nike,Women's Athletic Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Womens,Athletic Shoes,Sneakers,Nike",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Womens,Athletic Shoes,Sneakers,Nike,Women's Casual Shoes",
#        "Clothing,Shoes,Women's Shoes,All Women's Shoes,Womens Shoes,Womens Sandals & Flip Flops,Womens Sport Sandals,Womens,Sandals,Nike",
#        'Womens,Shoes,Sandals,Betula by Birkenstock',
#        'Womens,Shoes,Boots,Kisses by 2 Lips Too',
#        'Womens,Shoes,Pumps,Heels,2 Lips Too',
#        'Womens,Shoes,Boots,2 Lips Too',
#        "Womens,Shoes,Athletic Shoes,Sneakers,Nike,Clothing,Men's Shoes,Men's Athletic Shoes",
#        'Womens,Shoes,Athletic Shoes,Sneakers,madden NYC',
#        'Womens,Shoes,Sandals,REEF', 'Womens,Shoes,Flats,Unionbay',
#        'Womens,Shoes,Clogs,Mules,Unionbay',
#        "Womens,Shoes,Athletic Shoes,Sneakers,K-Swiss,Clothing,Women's Shoes,Women's Casual Shoes",
#        'Womens,Shoes,Boots,sugar', 'Womens,Shoes,Pumps,Heels,Rampage',
#        "Clothing,Shoes,Womens Shoes,Womens Casual Shoes,Women's Shoes,Women's Casual Shoes,Womens,Athletic Shoes,Sneakers,Skechers,All Women's Shoes",
#        'Womens,Shoes,Loafers,Clarks',
#        "Womens,Shoes,Athletic Shoes,Sneakers,ASICS,Clothing,Women's Shoes,All Women's Shoes,Sporting Goods,Fitness, Running & Yoga,Women",
#        'Womens,Shoes,Athletic Shoes,Sneakers,ASICS',
#        "Womens,Shoes,Athletic Shoes,Sneakers,ASICS,Clothing,Women's Shoes,Women's Casual Shoes",
#        'Womens,Shoes,Flats,Spring Step',
#        "Womens,Shoes,Flats,Spring Step,Clothing,Women's Shoes,All Women's Shoes",
#        'Womens,Shoes,Pumps,Heels,Easy Street',
#        "Womens,Shoes,Athletic Shoes,Sneakers,Easy Street,Clothing,Women's Shoes,All Women's Shoes",
#        'Womens,Shoes,Loafers,Easy Street',
#        'Womens,Shoes,Sandals,Easy Street',
#        "Womens,Shoes,Sandals,Easy Street,Clothing,Women's Shoes,All Women's Shoes",
#        "Womens,Shoes,Sandals,Easy Street,Women's Shoes,Clothing,All Women's Shoes",
#        'Womens,Shoes,Sandals,New Balance',
#        "Women's Trail Running Shoes,Women's Footwear,Women's Running Shoes",
#        "Women's Road Running Shoes,Women's Footwear,Women's Running Shoes",
#        "Women's Casual Boots & Shoes,Women's Casual Shoes,Women's Footwear",
#        "Women's Red Wing Shoes,Women's Clothing,Women's Shoes",
#        "Women's Clothing,Women's Shoes,Women's Red Wing Shoes",
#        "Women's Clothing,Women's Shoes,Women's New Balance Shoes",
#        "Women's Footwear,Women's Running Shoes,Women's Trail Running Shoes",
#        "Women's Footwear,Women's Running Shoes,Women's Road Running Shoes",
#        "Women's Footwear,Women's Casual Boots & Shoes,Women's Casual Shoes"],
#       dtype=object)

# %%
# Quali sono le possibili categorie 
rows = dataset["categories"].unique()
#print(rows)
s = set()
for row in rows:
    #print("-- " + row)
    categories = row.split(",")
    for category in categories:
        ##print("---- " + category)
        s.add(category)

print(s)
# Out:
# {'Clothing', 'Athletic Shoes', 'madden NYC', 'Oxfords', 'New Balance', 'Easy Street', 'adidas', 'Simply Vera Vera Wang', 'K-Swiss', "Men's Athletic Shoes", 'Under Armour', 'Andrew Geller', "Women's Slippers", "Women's Trail Running Shoes", 'Low Slide Sandals', 'Comfort', 'Boat Shoes', "Boys' Shoes", "Women's Dress Shoes", 'Forever Collectibles', 'NaturalSoul by naturalizer', 'Henry Ferrera', 'Womens Oxfords', 'Qupid', 'sugar', 'Athletic', 'Sneakers', 'Clarks', "Men's Shoes", 'Ryka', "Women's Shoes", 'All Womens Shoes', 'Baby & Toddler Shoes', 'Eastland', 'LC Lauren Conrad', 'Style Charles by Charles David', "Women's Wear to Work", "Girls' Shoes", "Women's Clothing", 'ASICS', 'Rampage', 'Womens Casual Shoes', "Candie's", 'Jennifer Lopez', 'Corkys', 'Herstar', 'Rocky 4EurSole', "All Women's Shoes", ' Shoes & Accessories', 'Other Slip-Ons', 'Koolaburra by UGG', "Women's Road Running Shoes", 'Lugz', 'FILA', 'Apt. 9', 'A2 by Aerosoles', 'Barrow', 'Home Improvement', 'Betula by Birkenstock', 'Clogs', "Women's Boots", 'Womens Comfort Boots & Booties', 'NYLA', 'Womens Shoes', 'Dolce by Mojo Moxy', 'Olivia Miller', '2 Lips Too', 'LifeStride', 'PUMA', 'Pumps', 'SONOMA Goods for Life', 'Kisses by 2 Lips Too', 'Womens Comfort', "Women's Work & Safety Shoes", 'Sandals & Flip Flops', 'Sporting Goods', 'Nike', ' Running & Yoga', 'Vans', 'Slip-ons', 'Soft Style by Hush Puppies', 'Womens Sport Sandals', 'Journee Collection', 'Heels', "Women's Casual Shoes", 'Women', "All Men's Shoes", 'Fergalicious', 'Shoes', 'Spring Step', 'Laredo', 'Mules', "Women's New Balance Shoes", 'Slippers', 'Womens Oxford & Loafers', "Women's Winter Boots", 'Keds', 'Unionbay', "Women's Running Shoes", 'Seven7', 'MUK LUKS', 'Skechers', 'REEF', "Women's Footwear", "Dr. Scholl's", "Women's Athletic Shoes", 'Croft', 'Sandals', 'Cowboy Boots', 'Womens', 'Fitness', "Girls' Boots", 'Womens Sandals & Flip Flops', "Women's Casual Boots & Shoes", "Women's Sandals", 'Mid-Calf Boots', "Women's Red Wing Shoes", 'Work Safety Clothing and Equipment', "Men's Casual Shoes", 'Loafers', 'Boots', 'Flats', 'Baby & Kids Shoes', 'Shop by Clothing Type'}

# %% [markdown]
# ## Dataset Scarpe da Uomo

# %%
# I dataset sono forniti in .zip, il codice sottostante permette di unzippare i file 
# per ottenre i .csv contenuti.

import zipfile
import os

def print_file_list():
    for root, dirs, files in os.walk("dataset"):
       for name in files:
          print(os.path.join(root, name))
            
def unzip(dataset):
    zip_path = os.path.join("dataset", dataset)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall("dataset")
    
print('unzipping man shoes')    
unzip('man-shoes.zip')

print_file_list()
# Out:
# unzipping man shoes
# dataset\.gitignore
# dataset\7210_1.csv
# dataset\Datafiniti_Mens_Shoe_Prices.csv
# dataset\Datafiniti_Womens_Shoes.csv
# dataset\Datafiniti_Womens_Shoes_Jun19.csv
# dataset\info.md
# dataset\man-shoes.zip
# dataset\woman-shoes.zip

# %%
import pandas as pd
import os

# Questa modalità carica il CSV ignorando le righe errate ma stampando un relativo warning
dataset = pd.read_csv( os.path.join("dataset", "Datafiniti_Mens_Shoe_Prices.csv"), error_bad_lines=False, warn_bad_lines=False, low_memory=False )

# %%
pd.set_option("display.max_columns", 40)
dataset
# Out:
#                          id asins                brand  \
# 0      AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 1      AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 2      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 3      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 4      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# ...                     ...   ...                  ...
# 19310  AVpfdSjlilAPnD_xcGPm   NaN           Xray, XRay
# 19311  AVpf3bFWilAPnD_xjrQ2   NaN                 Fila
# 19312  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
# 19313  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
# 19314  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
#
#                                               categories colors  count  \
# 0             Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 1             Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 2             All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 3             All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# 4             All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# ...                                                  ...    ...    ...
# 19310    Clothing, Shoes & Accessories,Men's Shoes,Boots  Black    NaN
# 19311         Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 19312  Women's Sunglasses,Sunglasses,Bags & Accessori...    NaN    NaN
# 19313  Women's Sunglasses,Sunglasses,Bags & Accessori...    NaN    NaN
# 19314  Women's Sunglasses,Sunglasses,Bags & Accessori...    NaN    NaN
#
#                   dateAdded           dateUpdated  \
# 0      2016-11-07T00:45:12Z  2016-11-07T00:45:12Z
# 1      2016-11-07T00:45:12Z  2016-11-07T00:45:12Z
# 2      2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# 3      2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# 4      2016-06-14T04:29:57Z  2016-07-09T20:26:48Z
# ...                     ...                   ...
# 19310  2016-03-04T05:54:20Z  2016-03-04T05:54:20Z
# 19311  2016-10-05T22:23:17Z  2016-10-05T22:23:17Z
# 19312  2016-01-02T02:39:11Z  2016-04-05T23:07:58Z
# 19313  2016-01-02T02:39:11Z  2016-04-05T23:07:58Z
# 19314  2016-01-02T02:39:11Z  2016-04-05T23:07:58Z
#
#                                             descriptions           dimension  \
# 0      [{"dateSeen":["2016-11-07T00:45:12Z"],"sourceU...                 NaN
# 1      [{"dateSeen":["2016-11-07T00:45:12Z"],"sourceU...                 NaN
# 2      [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...                 NaN
# 3      [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...                 NaN
# 4      [{"dateSeen":["2016-07-09T20:26:48Z"],"sourceU...                 NaN
# ...                                                  ...                 ...
# 19310                                                NaN                 NaN
# 19311  [{"dateSeen":["2016-10-05T22:23:17Z"],"sourceU...                 NaN
# 19312                                                NaN  1 in x 1 in x 1 in
# 19313                                                NaN  1 in x 1 in x 1 in
# 19314                                                NaN  1 in x 1 in x 1 in
#
#                 ean                                           features  \
# 0      6.993020e+11  [{"key":"Gender","value":["Men"]},{"key":"Shoe...
# 1      6.993020e+11  [{"key":"Gender","value":["Men"]},{"key":"Shoe...
# 2               NaN  [{"key":"Gender","value":["Men"]},{"key":"Colo...
# 3               NaN  [{"key":"Gender","value":["Men"]},{"key":"Colo...
# 4               NaN  [{"key":"Gender","value":["Men"]},{"key":"Colo...
# ...             ...                                                ...
# 19310  6.574867e+11  [{"key":"Style","value":["Desert Boots"]},{"ke...
# 19311  7.894822e+11  [{"key":"Shoe Size","value":["9.5"]},{"key":"G...
# 19312           NaN  [{"key":"Gender","value":["Unisex"]},{"key":"F...
# 19313           NaN  [{"key":"Gender","value":["Unisex"]},{"key":"F...
# 19314           NaN  [{"key":"Gender","value":["Unisex"]},{"key":"F...
#
#        flavors                                          imageURLs  isbn  \
# 0          NaN  https://i5.walmartimages.com/asr/13ac3d61-003c...   NaN
# 1          NaN  https://i5.walmartimages.com/asr/13ac3d61-003c...   NaN
# 2          NaN  http://i5.walmartimages.com/dfw/dce07b8c-5844/...   NaN
# 3          NaN  http://i5.walmartimages.com/dfw/dce07b8c-5844/...   NaN
# 4          NaN  http://i5.walmartimages.com/dfw/dce07b8c-5844/...   NaN
# ...        ...                                                ...   ...
# 19310      NaN  http://i.ebayimg.com/images/g/d1kAAOSwCypWnEf9...   NaN
# 19311      NaN  https://i5.walmartimages.com/asr/cf14adbe-dba8...   NaN
# 19312      NaN  http://c.shld.net/rpx/i/s/pi/mp/10138237/prod_...   NaN
# 19313      NaN  http://c.shld.net/rpx/i/s/pi/mp/10138237/prod_...   NaN
# 19314      NaN  http://c.shld.net/rpx/i/s/pi/mp/10138237/prod_...   NaN
#
#                                                     keys manufacturer  \
# 0           josmo/8190wnavy75,699302044036,0699302044036          NaN
# 1           josmo/8190wnavy75,699302044036,0699302044036          NaN
# 2                          servusbyhoneywell/zsr101blmlg          NaN
# 3                          servusbyhoneywell/zsr101blmlg          NaN
# 4                          servusbyhoneywell/zsr101blmlg          NaN
# ...                                                  ...          ...
# 19310  newxrayhestermenslaceupbootsblacksize12/281938...          NaN
# 19311                         789482167691,0789482167691      unknown
# 19312  seekoptics/0027040801,seekopticsnewseekpolariz...          NaN
# 19313  seekoptics/0027040801,seekopticsnewseekpolariz...          NaN
# 19314  seekoptics/0027040801,seekopticsnewseekpolariz...          NaN
#
#       manufacturerNumber                                          merchants  \
# 0        8190-W-NAVY-7.5  [{"dateSeen":["2016-11-07T00:45:12Z"],"name":"...
# 1        8190-W-NAVY-7.5  [{"dateSeen":["2016-11-07T00:45:12Z"],"name":"...
# 2            ZSR101BLMLG  [{"dateSeen":["2016-06-14T04:29:57Z"],"name":"...
# 3            ZSR101BLMLG  [{"dateSeen":["2016-06-14T04:29:57Z"],"name":"...
# 4            ZSR101BLMLG  [{"dateSeen":["2016-06-14T04:29:57Z"],"name":"...
# ...                  ...                                                ...
# 19310        Xrw-151-Blk  [{"dateSeen":["2016-02-27T00:00:00Z"],"name":"...
# 19311                NaN  [{"dateSeen":["2016-10-05T22:23:17Z"],"name":"...
# 19312       0027-0408-01                                                NaN
# 19313       0027-0408-01                                                NaN
# 19314       0027-0408-01                                                NaN
#
#                                                     name  ...  \
# 0      Josmo 8190 Plain Infant Walking Shoes, Navy - ...  ...
# 1      Josmo 8190 Plain Infant Walking Shoes, Navy - ...  ...
# 2             Servus By Honeywell Shoe Studs Zsr101blmlg  ...
# 3             Servus By Honeywell Shoe Studs Zsr101blmlg  ...
# 4             Servus By Honeywell Shoe Studs Zsr101blmlg  ...
# ...                                                  ...  ...
# 19310  New Xray Hester Men's Lace Up Boots - Black - ...  ...
# 19311  Fila Men's Original Tennis Navy/white/gold Fas...  ...
# 19312  Seek Optics New Seek Polarized Replacement Len...  ...
# 19313  Seek Optics New Seek Polarized Replacement Len...  ...
# 19314  Seek Optics New Seek Polarized Replacement Len...  ...
#
#             prices.dateSeen prices.flavor prices.isSale  \
# 0      2016-11-05T00:00:00Z           NaN          true
# 1      2016-11-05T00:00:00Z           NaN         false
# 2      2016-03-08T00:00:00Z           NaN         false
# 3      2015-11-30T00:00:00Z           NaN         false
# 4      2016-04-29T00:00:00Z           NaN         false
# ...                     ...           ...           ...
# 19310  2016-02-27T00:00:00Z           NaN         false
# 19311  2016-10-05T00:00:00Z           NaN         false
# 19312  2016-03-17T00:00:00Z           NaN          true
# 19313  2016-03-31T00:00:00Z           NaN          true
# 19314  2016-03-31T00:00:00Z           NaN         false
#
#                         prices.merchant       prices.offer  \
# 0                                   NaN  REDUCED USD 12.10
# 1          UnbeatableSale - Walmart.com  REDUCED USD 12.10
# 2          SIM Supply Inc - Walmart.com                NaN
# 3          SIM Supply Inc - Walmart.com                NaN
# 4          SIM Supply Inc - Walmart.com                NaN
# ...                                 ...                ...
# 19310                               NaN                NaN
# 19311  ULTIMATE SHOE ZONE - Walmart.com                NaN
# 19312                  Seek Optics, Inc                NaN
# 19313                  Seek Optics, Inc                NaN
# 19314                  Seek Optics, Inc                NaN
#
#       prices.returnPolicy prices.shipping prices.size prices.source  \
# 0                     NaN             NaN         NaN           NaN
# 1                     NaN             NaN         NaN           NaN
# 2                     NaN             NaN         NaN           NaN
# 3                     NaN             NaN         NaN           NaN
# 4                     NaN             NaN         NaN           NaN
# ...                   ...             ...         ...           ...
# 19310                 NaN        USD 7.95         NaN           NaN
# 19311                 NaN             NaN         NaN           NaN
# 19312                 NaN             NaN         NaN           NaN
# 19313                 NaN             NaN         NaN           NaN
# 19314                 NaN             NaN         NaN           NaN
#
#                                        prices.sourceURLs prices.warranty  \
# 0      https://www.walmart.com/ip/Josmo-8190-Plain-In...             NaN
# 1      https://www.walmart.com/ip/Josmo-8190-Plain-In...             NaN
# 2      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...             NaN
# 3      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...             NaN
# 4      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...             NaN
# ...                                                  ...             ...
# 19310  http://www.ebay.com/itm/NEW-XRay-Hester-Mens-L...             NaN
# 19311  https://www.walmart.com/ip/Fila-Men-s-Original...             NaN
# 19312  http://www.sears.com/content/pdp/products/pric...             NaN
# 19313  http://www.sears.com/content/pdp/products/pric...             NaN
# 19314  http://www.sears.com/content/pdp/products/pric...             NaN
#
#       quantities reviews sizes  \
# 0            NaN     NaN   NaN
# 1            NaN     NaN   NaN
# 2            NaN     NaN   NaN
# 3            NaN     NaN   NaN
# 4            NaN     NaN   NaN
# ...          ...     ...   ...
# 19310        NaN     NaN    12
# 19311        NaN     NaN   NaN
# 19312        NaN     NaN   NaN
# 19313        NaN     NaN   NaN
# 19314        NaN     NaN   NaN
#
#                                                     skus  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19310  [{"sourceURLs":["http://www.ebay.com/itm/NEW-X...
# 19311                                                NaN
# 19312  [{"sourceURLs":["http://www.sears.com/content/...
# 19313  [{"sourceURLs":["http://www.sears.com/content/...
# 19314  [{"sourceURLs":["http://www.sears.com/content/...
#
#                                               sourceURLs           upc vin  \
# 0      https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.993020e+11 NaN
# 1      https://www.walmart.com/ip/Josmo-8190-Plain-In...  6.993020e+11 NaN
# 2      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...           NaN NaN
# 3      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...           NaN NaN
# 4      http://www.walmart.com/ip/Studs-Shoe-Large-Pr-...           NaN NaN
# ...                                                  ...           ...  ..
# 19310  http://www.ebay.com/itm/NEW-XRay-Hester-Mens-L...  6.574867e+11 NaN
# 19311  https://www.walmart.com/ip/Fila-Men-s-Original...  7.894822e+11 NaN
# 19312  http://www.sears.com/content/pdp/products/pric...           NaN NaN
# 19313  http://www.sears.com/content/pdp/products/pric...           NaN NaN
# 19314  http://www.sears.com/content/pdp/products/pric...           NaN NaN
#
#       websiteIDs  weight
# 0            NaN     NaN
# 1            NaN     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN
# ...          ...     ...
# 19310        NaN     NaN
# 19311        NaN     NaN
# 19312        NaN     NaN
# 19313        NaN     NaN
# 19314        NaN     NaN
#
# [19315 rows x 48 columns]

# %%
# Quali colonne esistono? Esempio di una riga...

cols = list(dataset.columns)
row = dataset.iloc[133]
for col in cols:
    print("col [" + col + "]: " + str( row[col] ))
    print()
# Out:
# col [id]: AVpfK2v-ilAPnD_xWbDm
#
# col [asins]: nan
#
# col [brand]: New Balance Numeric
#
# col [categories]: All Men's Shoes,Shoes,Men's Shoes,Clothing
#
# col [colors]: Beige
#
# col [count]: nan
#
# col [dateAdded]: 2017-01-09T20:24:33Z
#
# col [dateUpdated]: 2017-01-09T20:24:33Z
#
# col [descriptions]: [{"dateSeen":["2017-01-09T20:24:33Z"],"sourceURLs":["https://www.walmart.com/ip/New-Balance-Numeric-M254-Men-Round-Toe-Suede-Sneakers/322789959"],"value":"Important Made in USA Origin Disclaimer: For certain items sold by Walmart on Walmart.com, the displayed country of origin information may not be accurate or consistent with manufacturer information. For updated, accurate country of origin data, it is recommended that you rely on product packaging or manufacturer information. Brand Style - New Balance Numeric M254 Width - Medium (D, M) True Color - TNN Upper Material - Suede Outsole Material - Man-Made Heel Height - 0.75 Inches Brand Style - New Balance Numeric M254 Width - Medium (D, M) True Color - TNN Upper Material - Suede Outsole Material - Man-Made Heel Height - 0.75 Inches ps7212994"}]
#
# col [dimension]: nan
#
# col [ean]: 889969178612.0
#
# col [features]: [{"key":"Material","value":["Suede"]},{"key":"Gender","value":["Men"]},{"key":"Color","value":["Beige"]},{"key":"Model","value":["M254TNN"]},{"key":"Manufacturer Part Number","value":["M254TNN"]},{"key":"Brand","value":["New Balance Numeric"]},{"key":"Age Group","value":["Adult"]}]
#
# col [flavors]: nan
#
# col [imageURLs]: https://i5.walmartimages.com/asr/9749f4e8-494b-461a-af94-5c732859da68_1.b901b42f2287b3c967e142fa2337d597.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFFF
#
# col [isbn]: nan
#
# col [keys]: 889969178612,0889969178612,newbalancenumeric/m254tnn
#
# col [manufacturer]: New Balance Numeric
#
# col [manufacturerNumber]: M254TNN
#
# col [merchants]: [{"dateSeen":["2017-01-09T20:24:33Z"],"name":"Apparelsave"}]
#
# col [name]: New Balance Numeric M254 Men  Round Toe Suede Tan Sneakers
#
# col [prices.amountMin]: 47.99
#
# col [prices.amountMax]: 47.99
#
# col [prices.availability]: nan
#
# col [prices.color]: nan
#
# col [prices.condition]: new
#
# col [prices.count]: nan
#
# col [prices.currency]: USD
#
# col [prices.dateAdded]: 2017-01-09T20:24:33Z
#
# col [prices.dateSeen]: 2017-01-08T00:00:00Z
#
# col [prices.flavor]: nan
#
# col [prices.isSale]: true
#
# col [prices.merchant]: ApparelSave - Walmart.com
#
# col [prices.offer]: REDUCED USD 22.01
#
# col [prices.returnPolicy]: nan
#
# col [prices.shipping]: nan
#
# col [prices.size]: nan
#
# col [prices.source]: nan
#
# col [prices.sourceURLs]: https://www.walmart.com/ip/New-Balance-Numeric-M254-Men-Round-Toe-Suede-Sneakers/322789959
#
# col [prices.warranty]: nan
#
# col [quantities]: nan
#
# col [reviews]: nan
#
# col [sizes]: 10.5,8.5,10,7,6,9.5,9,11.5,8,13,11,12
#
# col [skus]: nan
#
# col [sourceURLs]: https://www.walmart.com/ip/New-Balance-Numeric-M254-Men-Round-Toe-Suede-Sneakers/322789959
#
# col [upc]: 889969178612.0
#
# col [vin]: nan
#
# col [websiteIDs]: nan
#
# col [weight]: nan

# %%
# Creare un dataset ridotto


import json
import math
import sys


def extract_material(features_json):
    # [{"key":"Material","value":["Suede"]},{"key":"Gender","value":["Men"]},{"key":"Color","value":["Beige"]},{"key":"Model","value":["M254TNN"]},{"key":"Manufacturer Part Number","value":["M254TNN"]},{"key":"Brand","value":["New Balance Numeric"]},{"key":"Age Group","value":["Adult"]}]    
    try:
        if (type(features_json) == float):
            return None
        
        if (type(features_json) != str):
            print( f"WARN not a string but a {type(features_json)} {features_json}" )
            return None
        
        features_json = features_json.replace("\\\\", "\\")
        kvs = json.loads(features_json)
        for kv in kvs:
            if(kv["key"] == "Material"):
                return kv["value"][0]
            
        return None
    except:
        err_type, err_value, err_traceback = sys.exc_info()
        print( f"WARN '{err_type}' '{err_value}' parsing {features_json}" )
        return None
    
def extract_age_group(features_json):
    try:
        if (type(features_json) == float):
            return None
        
        if (type(features_json) != str):
            print( f"WARN not a string but a {type(features_json)} {features_json}" )
            return None
        
        features_json = features_json.replace("\\\\", "\\")
        kvs = json.loads(features_json)
        for kv in kvs:
            if(kv["key"] == "Age Group"):
                return kv["value"][0]
        return None
    except:
        err_type, err_value, err_traceback = sys.exc_info()
        print( f"WARN '{err_type}' '{err_value}' parsing {features_json}" )
        return None    

reduced_dataset = pd.DataFrame()
reduced_dataset["brand"] = dataset["brand"]
reduced_dataset["material"] = dataset["features"].apply( extract_material )
reduced_dataset["age_group"] = dataset["features"].apply( extract_age_group )
reduced_dataset["prices.amountMin"] = pd.to_numeric(dataset["prices.amountMin"], errors='coerce')
reduced_dataset["prices.amountMax"] = pd.to_numeric(dataset["prices.amountMax"], errors='coerce')
reduced_dataset["prices.currency"] = dataset["prices.currency"]

reduced_dataset
# Out:
#                      brand material age_group  prices.amountMin  \
# 0                    Josmo     None      None             39.89
# 1                    Josmo     None      None             51.99
# 2      SERVUS BY HONEYWELL     None      None             40.02
# 3      SERVUS BY HONEYWELL     None      None             50.31
# 4      SERVUS BY HONEYWELL     None      None             46.26
# ...                    ...      ...       ...               ...
# 19310           Xray, XRay     None      None             29.95
# 19311                 Fila     None      None             64.95
# 19312          Seek Optics     None      None             32.48
# 19313          Seek Optics     None      None             31.48
# 19314          Seek Optics     None      None             72.00
#
#        prices.amountMax prices.currency
# 0                 39.89             USD
# 1                 51.99             USD
# 2                 40.02             USD
# 3                 50.31             USD
# 4                 46.26             USD
# ...                 ...             ...
# 19310             29.95             USD
# 19311             64.95             USD
# 19312             32.48             USD
# 19313             31.48             USD
# 19314             72.00             USD
#
# [19315 rows x 6 columns]

# %%
def extract_averge_review(reviews):
    try:
        if (type(reviews) == float):
            return None
        
        if (type(reviews) != str):
            #print( f"WARN not a string but a {type(reviews)} {reviews}" )
            return None
        
        reviews = reviews.replace("\\\\", "\\")
        kvs = json.loads(reviews)
        ratings = []
        for kv in kvs:
            if("rating" in kv):
                #print( f"\n\n{kv}" )
                ratings.append( float( kv["rating"] ) )
                
        #print( f"\n\n{ratings}" )
        
        if len(ratings) == 0:
            return None
        else:
            total = 0.0
            for r in ratings:
                total = total + r
            avg = total / len(ratings)
            return avg        
                
    except:
        err_type, err_value, err_traceback = sys.exc_info()
        #print( f"WARN '{err_type}' '{err_value}' parsing {reviews}" )
        return None 
    


# Questo crea una colonna con il valore medio delle review per quel prodotto
reduced_dataset["reviews"] = dataset["reviews"].apply( extract_averge_review )

# Questo è solo per ispezionare le righe che hanno un qualche valore di recensione
reduced_dataset[ reduced_dataset["reviews"].isnull()==False ]
# Out:
#              brand   material age_group  prices.amountMin  prices.amountMax  \
# 900       Chippewa    Leather     Adult            183.99            183.99
# 901       Chippewa    Leather     Adult            230.00            230.00
# 902       Chippewa    Leather     Adult            215.95            215.95
# 4327   New Balance    Leather     Adult            154.34            154.34
# 4328   New Balance    Leather     Adult             76.95             76.95
# ...            ...        ...       ...               ...               ...
# 17246     Chippewa    Leather     Adult            175.95            175.95
# 18472  New Balance  Synthetic     Adult            145.00            145.00
# 18473  New Balance  Synthetic     Adult             86.99             86.99
# 18474  New Balance  Synthetic     Adult             79.99             79.99
# 18475  New Balance  Synthetic     Adult             84.95             84.95
#
#       prices.currency  reviews
# 900               USD      4.0
# 901               USD      4.0
# 902               USD      4.0
# 4327              USD      3.6
# 4328              USD      3.6
# ...               ...      ...
# 17246             USD      5.0
# 18472             USD      3.4
# 18473             USD      3.4
# 18474             USD      3.4
# 18475             USD      3.4
#
# [84 rows x 7 columns]

# %%
reduced_dataset = reduced_dataset.dropna()

#reduced_dataset

#reduced_dataset["prices.currency"].value_counts()
#reduced_dataset["brand"].value_counts()
reduced_dataset.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A09F8BAAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A09F8CFD88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A09F8F2548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A09F926EC8>]],
#       dtype=object)
