# %%
import pandas as pd


women_shoes = pd.concat(map(pd.read_csv, ['Datafiniti_Womens_Shoes.csv', 'Datafiniti_Womens_Shoes_Jun19.csv', '7210_1.csv']))
women_shoes
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (13,16,18,22,24,32,33,40,41,47,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                          id             dateAdded           dateUpdated  \
# 0      AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z
# 1      AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z
# 2      AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z
# 3      AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z
# 4      AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z
# ...                     ...                   ...                   ...
# 33796  AVsUxZClnnc1JgDc4Mev  2017-03-28T11:55:43Z  2017-03-28T11:55:43Z
# 33797  AVsUyEcaU2_QcyX9Pb4g  2017-03-28T11:58:41Z  2017-03-28T11:58:41Z
# 33798  AVsUyEcaU2_QcyX9Pb4g  2017-03-28T11:58:41Z  2017-03-28T11:58:41Z
# 33799  AVticmzVnnc1JgDc5Uym  2017-04-12T13:55:17Z  2017-04-13T20:44:29Z
# 33800  AVtidDQ-nnc1JgDc5U4Q  2017-04-12T13:57:14Z  2017-04-13T20:41:27Z
#
#             asins            brand  \
# 0             NaN      Naturalizer
# 1             NaN         MUK LUKS
# 2             NaN         MUK LUKS
# 3             NaN         MUK LUKS
# 4             NaN         MUK LUKS
# ...           ...              ...
# 33796         NaN           Novica
# 33797         NaN           Novica
# 33798         NaN           Novica
# 33799  B06XZJTJBT  City Classified
# 33800  B0188Y3WM2           Vionic
#
#                                               categories primaryCategories  \
# 0      Clothing,Shoes,Women's Shoes,All Women's Shoes...             Shoes
# 1      Clothing,Shoes,Women's Shoes,Women's Casual Sh...             Shoes
# 2      Clothing,Shoes,Women's Shoes,Women's Casual Sh...             Shoes
# 3      Clothing,Shoes,Women's Shoes,All Women's Shoes...       Shoes,Shoes
# 4      Clothing,Shoes,Women's Shoes,All Women's Shoes...             Shoes
# ...                                                  ...               ...
# 33796            Access.,Clothing,Shoes,Women's Clothing               NaN
# 33797            Access.,Clothing,Shoes,Women's Clothing               NaN
# 33798            Access.,Clothing,Shoes,Women's Clothing               NaN
# 33799                        Clothing,,Women,Shoes,Pumps               NaN
# 33800                      Women,Shoes,Sandals,Clothing,               NaN
#
#                                colors                 dimension           ean  \
# 0      Silver,Cream Watercolor Floral                       NaN           NaN
# 1                                Grey                       NaN  3.397705e+10
# 2                                Grey                       NaN  3.397705e+10
# 3                               Black  6.0 in x 6.0 in x 1.0 in  3.397705e+10
# 4                                Grey  6.0 in x 6.0 in x 1.0 in  3.397705e+10
# ...                               ...                       ...           ...
# 33796                            Blue                       NaN           NaN
# 33797                             Red             30 in x 31 in           NaN
# 33798                             Red             30 in x 31 in           NaN
# 33799                             NaN                       NaN           NaN
# 33800                             NaN                       NaN           NaN
#
#        ... prices.warranty                                         quantities  \
# 0      ...             NaN                                                NaN
# 1      ...             NaN                                                NaN
# 2      ...             NaN                                                NaN
# 3      ...             NaN                                                NaN
# 4      ...             NaN                                                NaN
# ...    ...             ...                                                ...
# 33796  ...             NaN  [{"dateSeen":["2017-03-26T10:04:21.331Z"],"sou...
# 33797  ...             NaN  [{"dateSeen":["2017-03-26T18:48:59.335Z"],"sou...
# 33798  ...             NaN  [{"dateSeen":["2017-03-26T18:48:59.335Z"],"sou...
# 33799  ...             NaN                                                NaN
# 33800  ...             NaN                                                NaN
#
#       reviews                                               skus vin  \
# 0         NaN                                                NaN NaN
# 1         NaN                                                NaN NaN
# 2         NaN                                                NaN NaN
# 3         NaN                                                NaN NaN
# 4         NaN                                                NaN NaN
# ...       ...                                                ...  ..
# 33796     NaN  [{"sourceURLs":["https://www.overstock.com/Wor... NaN
# 33797     NaN  [{"sourceURLs":["https://www.overstock.com/Wor... NaN
# 33798     NaN  [{"sourceURLs":["https://www.overstock.com/Wor... NaN
# 33799     NaN                                                NaN NaN
# 33800     NaN                                                NaN NaN
#
#        websiteIDs  Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51
# 0             NaN          NaN         NaN         NaN         NaN
# 1             NaN          NaN         NaN         NaN         NaN
# 2             NaN          NaN         NaN         NaN         NaN
# 3             NaN          NaN         NaN         NaN         NaN
# 4             NaN          NaN         NaN         NaN         NaN
# ...           ...          ...         ...         ...         ...
# 33796         NaN          NaN         NaN         NaN         NaN
# 33797         NaN          NaN         NaN         NaN         NaN
# 33798         NaN          NaN         NaN         NaN         NaN
# 33799         NaN          NaN         NaN         NaN         NaN
# 33800         NaN          NaN         NaN         NaN         NaN
#
# [53801 rows x 54 columns]

# %%
women_shoes.info()

# %%
women_shoes['brand'] = women_shoes['brand'].str.replace('journee collection', 'Journee Collection ')
women_shoes

# %%
women_shoes['brand'].value_counts().head(n=20)

# %%
women_shoes.info()

# %%
women_shoes = women_shoes[['brand','categories', 'prices.amountMax', 'prices.amountMin','prices.currency', 'colors', 'name','sizes','features','reviews']]
women_shoes
# Out:
#                  brand                                         categories  \
# 0          Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# ...                ...                                                ...
# 33796           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33797           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33798           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33799  City Classified                        Clothing,,Women,Shoes,Pumps
# 33800           Vionic                      Women,Shoes,Sandals,Clothing,
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 0                 55.99             55.99             USD
# 1                 47.00             35.25             USD
# 2                 35.25             35.25             USD
# 3                 24.75             24.75             USD
# 4                 33.00             30.39             USD
# ...                 ...               ...             ...
# 33796             43.19             43.19             USD
# 33797             39.99             39.99             USD
# 33798             35.99             35.99             USD
# 33799             25.64             25.64             USD
# 33800             47.99             47.99             USD
#
#                                colors  \
# 0      Silver,Cream Watercolor Floral
# 1                                Grey
# 2                                Grey
# 3                               Black
# 4                                Grey
# ...                               ...
# 33796                            Blue
# 33797                             Red
# 33798                             Red
# 33799                             NaN
# 33800                             NaN
#
#                                                     name  \
# 0      Naturalizer Danya Women N/S Open Toe Synthetic...
# 1                    MUK LUKS Womens Jane Suede Moccasin
# 2                    MUK LUKS Womens Jane Suede Moccasin
# 3               MUK LUKS Womens Dawn Suede Scuff Slipper
# 4               MUK LUKS Womens Dawn Suede Scuff Slipper
# ...                                                  ...
# 33796  Handcrafted Cotton Blend 'Garden in Blue' Card...
# 33797  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33798  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33799  City Classified Women's Closed Toe Mary Jane C...
# 33800                        Vionic Women's Jura Sandals
#
#                                                    sizes  \
# 0      6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                             10,7,6,9,8
# 2                                             10,7,6,9,8
# 3                                             10,7,6,9,8
# 4                                             10,7,6,9,8
# ...                                                  ...
# 33796                                                NaN
# 33797                                                NaN
# 33798                                                NaN
# 33799                                                NaN
# 33800                                                NaN
#
#                                                 features reviews
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 33796  [{"key":"Worldstock Country","value":["Peru"]}...     NaN
# 33797  [{"key":"Worldstock Country","value":["Peru"]}...     NaN
# 33798  [{"key":"Worldstock Country","value":["Peru"]}...     NaN
# 33799                                                NaN     NaN
# 33800                                                NaN     NaN
#
# [53801 rows x 10 columns]

# %%
import json
import math
import sys


def extract_averge_review(reviews):
    try:
        if (type(reviews) == float):
            return None
        
        if (type(reviews) != str):
            #print( f"WARN not a string but a {type(reviews)} {reviews}" )
            return None
        
        reviews = reviews.replace("\\\\", "\\")
        kvs = json.loads(reviews)
        ratings = []
        for kv in kvs:
            if("rating" in kv):
                #print( f"\n\n{kv}" )
                ratings.append( float( kv["rating"] ) )
                
        #print( f"\n\n{ratings}" )
        
        # questo blocco è per fare qualcosa di utile con i voti di un prodotto.
        # ad esempio in questo caso viene calcolata la media delle recensioni
        if len(ratings) == 0:
            return None
        else:
            total = 0.0
            for r in ratings:
                total = total + r
            avg = total / len(ratings)
            return avg        
                
    except:
        err_type, err_value, err_traceback = sys.exc_info()
        #print( f"WARN '{err_type}' '{err_value}' parsing {reviews}" )
        return None

# %%
reduced_women = pd.DataFrame()
reduced_women['brand'] = women_shoes['brand']
reduced_women['categories'] = women_shoes['categories']
reduced_women['prices.amountMax'] = women_shoes['prices.amountMax']
reduced_women['prices.amountMin'] = women_shoes['prices.amountMin']
reduced_women['prices.currency'] = women_shoes['prices.currency']
reduced_women['colors'] = women_shoes['colors'] 
reduced_women['name'] = women_shoes['name']
reduced_women['sizes'] = women_shoes['sizes'] 
reduced_women['features'] = women_shoes['features']
reduced_women['reviews'] = women_shoes['reviews'].apply(extract_averge_review)
reduced_women
# Out:
#                  brand                                         categories  \
# 0          Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# ...                ...                                                ...
# 33796           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33797           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33798           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33799  City Classified                        Clothing,,Women,Shoes,Pumps
# 33800           Vionic                      Women,Shoes,Sandals,Clothing,
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 0                 55.99             55.99             USD
# 1                 47.00             35.25             USD
# 2                 35.25             35.25             USD
# 3                 24.75             24.75             USD
# 4                 33.00             30.39             USD
# ...                 ...               ...             ...
# 33796             43.19             43.19             USD
# 33797             39.99             39.99             USD
# 33798             35.99             35.99             USD
# 33799             25.64             25.64             USD
# 33800             47.99             47.99             USD
#
#                                colors  \
# 0      Silver,Cream Watercolor Floral
# 1                                Grey
# 2                                Grey
# 3                               Black
# 4                                Grey
# ...                               ...
# 33796                            Blue
# 33797                             Red
# 33798                             Red
# 33799                             NaN
# 33800                             NaN
#
#                                                     name  \
# 0      Naturalizer Danya Women N/S Open Toe Synthetic...
# 1                    MUK LUKS Womens Jane Suede Moccasin
# 2                    MUK LUKS Womens Jane Suede Moccasin
# 3               MUK LUKS Womens Dawn Suede Scuff Slipper
# 4               MUK LUKS Womens Dawn Suede Scuff Slipper
# ...                                                  ...
# 33796  Handcrafted Cotton Blend 'Garden in Blue' Card...
# 33797  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33798  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33799  City Classified Women's Closed Toe Mary Jane C...
# 33800                        Vionic Women's Jura Sandals
#
#                                                    sizes  \
# 0      6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                             10,7,6,9,8
# 2                                             10,7,6,9,8
# 3                                             10,7,6,9,8
# 4                                             10,7,6,9,8
# ...                                                  ...
# 33796                                                NaN
# 33797                                                NaN
# 33798                                                NaN
# 33799                                                NaN
# 33800                                                NaN
#
#                                                 features  reviews
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                                                    NaN      NaN
# 3                                                    NaN      NaN
# 4                                                    NaN      NaN
# ...                                                  ...      ...
# 33796  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33797  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33798  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33799                                                NaN      NaN
# 33800                                                NaN      NaN
#
# [53801 rows x 10 columns]

# %%
reduced_women['medium_price'] = (reduced_women['prices.amountMax']+reduced_women['prices.amountMin'])/2
reduced_women
# Out:
#                  brand                                         categories  \
# 0          Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# ...                ...                                                ...
# 33796           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33797           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33798           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33799  City Classified                        Clothing,,Women,Shoes,Pumps
# 33800           Vionic                      Women,Shoes,Sandals,Clothing,
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 0                 55.99             55.99             USD
# 1                 47.00             35.25             USD
# 2                 35.25             35.25             USD
# 3                 24.75             24.75             USD
# 4                 33.00             30.39             USD
# ...                 ...               ...             ...
# 33796             43.19             43.19             USD
# 33797             39.99             39.99             USD
# 33798             35.99             35.99             USD
# 33799             25.64             25.64             USD
# 33800             47.99             47.99             USD
#
#                                colors  \
# 0      Silver,Cream Watercolor Floral
# 1                                Grey
# 2                                Grey
# 3                               Black
# 4                                Grey
# ...                               ...
# 33796                            Blue
# 33797                             Red
# 33798                             Red
# 33799                             NaN
# 33800                             NaN
#
#                                                     name  \
# 0      Naturalizer Danya Women N/S Open Toe Synthetic...
# 1                    MUK LUKS Womens Jane Suede Moccasin
# 2                    MUK LUKS Womens Jane Suede Moccasin
# 3               MUK LUKS Womens Dawn Suede Scuff Slipper
# 4               MUK LUKS Womens Dawn Suede Scuff Slipper
# ...                                                  ...
# 33796  Handcrafted Cotton Blend 'Garden in Blue' Card...
# 33797  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33798  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33799  City Classified Women's Closed Toe Mary Jane C...
# 33800                        Vionic Women's Jura Sandals
#
#                                                    sizes  \
# 0      6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                             10,7,6,9,8
# 2                                             10,7,6,9,8
# 3                                             10,7,6,9,8
# 4                                             10,7,6,9,8
# ...                                                  ...
# 33796                                                NaN
# 33797                                                NaN
# 33798                                                NaN
# 33799                                                NaN
# 33800                                                NaN
#
#                                                 features  reviews  \
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                                                    NaN      NaN
# 3                                                    NaN      NaN
# 4                                                    NaN      NaN
# ...                                                  ...      ...
# 33796  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33797  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33798  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33799                                                NaN      NaN
# 33800                                                NaN      NaN
#
#        medium_price
# 0            55.990
# 1            41.125
# 2            35.250
# 3            24.750
# 4            31.695
# ...             ...
# 33796        43.190
# 33797        39.990
# 33798        35.990
# 33799        25.640
# 33800        47.990
#
# [53801 rows x 11 columns]

# %%
rows = reduced_women["categories"].unique()
#print(rows)
s = set()
for row in rows:
    #print("-- " + row)
    categories = row.split(",")
    for category in categories:
        ##print("---- " + category)
        s.add(category)

print(s)
# Out:
# {'', 'Eastland', 'Heeled', 'Loafers', 'Loafers Slip-Ons', 'Rampage', 'Collectible Figurines', "Women's Running Shoes", 'Peep Toe', '#805 in', 'Shapewear', 'Character Shop', 'Worldstock Fair Trade', 'Collection', 'All Boys Shoes', 'Asics', "Women's Athletic Shoes", 'Racing', 'All Womens Shoes', 'MUK LUKS', 'Enzo Angiolini', '#1757 in', 'Swimming', 'Delicious', 'Scrubs', 'See more Louise Et Cie Esperance Women US 10.5 Black Sl...', 'All Costumes', '#3580 in', "Girls' Boots", 'Leisureland', 'Jumpsuits & Rompers', 'Nina', 'Fastpitch Softball Cleats', 'Other Slip-Ons', 'Watches', ' Running & Yoga', 'Premium Womens Comfort', 'Bikes', "Women's Boots", 'Toning Shoes', 'Bellini', '#350 in', 'Basketball', 'Mid-Calf', 'Stability', 'Easter Gifts', '#3591 in', 'Special Offers', "See more Women's Minnetonka Moccasin Thunderbird II Moc...", 'Cell', 'Specialty Shops', 'Womens Comfort Boots & Booties', "All Women's Clothing", "Women's Workwear & Uniforms", 'NaturalSoul by naturalizer', 'Team Sports', 'Wide Calf', '#23703 in', 'Figurines', 'Croft', 'Apparel & Accessories', 'Slip-ons', 'See more Khombu 0650 Womens JAS Black Leather Winter BO...', 'Knee-High', 'Racquet Sports', '483          in', "Women's Flats", 'household essentials', 'Medicine Cabinet', 'Clarks', '#10000 in', '#50297 in', "Women's Skirts", "Women's Scrubs", 'Golf', 'Shop by Clothing Type', "Women's Trail Running Shoes", 'Moccasin Slippers', 'Home', 'All Wide Shoes', 'Platforms & Wedges', 'Baseball Cleats', '#3', 'New Arrivals', 'Home Décor', 'Outdoor', 'Rain', 'Soft Style by Hush Puppies', 'Ellie', 'American Rag', 'Qupid', '#23880 in', 'Pin Up', 'See more BCBGeneration 5280 Womens Kurt Brown Leather H...', 'Lamo', "Girl's Accessories", '#989 in', 'Brinley Co.', 'BETANI', 'See more VANS Authentic Lo Pro Cosmic Galaxy Black Blue...', 'Azura', 'See more Harley-Davidson Summer Womens Black Leather Sl...', 'toys', "Girls' Shoes", 'See more Michael Kors Fulton MOC Washed Denim Shoes Fla...', 'Casual Lace', 'Petite Swimsuits', 'Girls Slippers', 'Womens Sandals Flip-flops', 'Boot Bags', 'Spring Step', "Women's Accessories", 'Dance', 'Troentorp Bastad Clogs', 'Boys Shoes', 'Easy Street', '#341 in', 'See more ALDO 6422 Womens Vitaly Black Leather HEELS Kn...', 'Womens Over-the-knee Boots', 'A2 by Aerosoles', 'Anne Klein', 'Crocs', 'Acorn', 'Betula by Birkenstock', 'Sandals', "Boys' Shoes", 'Keds', 'Under Armour', 'Fergalicious', 'Mules', 'Teen Girl', "Women's Character Shop", "Women's Watches", 'Knee-High Boots', 'Refresh', ' Accessories', '944 in', 'Travel Duffels', 'Apt. 9', 'Cowboy Boots', 'Gladiator', 'Water Shoes', 'Boat Shoes', 'adidas', 'All Womens Flats', '#97541 in', 'Unionbay', "Women's Weather Boots", 'FIC', '#37 in', 'Lugz', 'See more Born Silvie Women US 10 Black Loafer Pre Owned...', 'Protective Gear', "Women's Casual Shoes", 'Mark and Maddux', 'Adidas', '#2616 in', 'Gotta Flurt', 'Lane Boots', 'See more LifeStride 9770 Womens Sasha Black Riding BOOT...', 'See more Easy Spirit Dorlisa Women US 8 Blue Mules Blem...', 'Access.', 'Uniforms', "Men's Protective Eyewear", 'Rain Boots', "Women's Dress Shoes", 'LifeStride', 'Fragrances', 'Womens Oxford & Loafers', "Women's Slippers", '#101628 in', 'All Halloween Costumes', 'Power Tools', 'Shoes Boots', 'Wild Diva', ' Shoes', 'See more Cole Haan 6200 Womens Stephanie Air OT Taupe P...', 'Winter Shoes', "Women's Suits & Sets", 'See more Mizuno 9spike Swift 4 Womens Metal Softball Cl...', 'Equestrian Sports', 'SONOMA Goods for Life', '#3531 in', "Women's Footwear", 'Koolaburra by UGG', 'Athletic Shoes', "Women's Road Running Shoes", 'Heeled Sandals', "Women's Clothing", 'Fastpitch Softball', '#6904 in', 'Boys', 'See more Fashion Focus Ea45 Womens Platform Flip-flop C...', '#544 in', 'Womens Sandals & Flip Flops', 'Slip Ons/Moc', 'Walking', 'See more Women Bearpaw Knit Tall Boot 658w Black 100 Au...', "Women's Designer Shoes", 'Ankle Straps', "All Juniors' Clothing", "Women's Cleats", 'Fine', 'Infinity', 'All Girls Shoes', 'Womens Oxf ...

# %%
to_save = ['Sneakers', 'Fashion Sneakers','Nike', 'Team Sports', 'Sports', 'Adidas', 'Basketball','Gravity Defyer',"Womens' Athletic Shoes",'Trendsetter','Athletic', 'Slip-ons','Skateboarding', 'Basketball Shoes','Running','Walking Shoes', 'Running Shoes',"Women's Athletic Shoes", "See more ASICS Women's Gel-nimbus 16 Running Shoe Light...", 'Skechers']
def cat_def(x):
    p = ''
    for cat_to_save in to_save:
        if cat_to_save in x :
            return cat_to_save

   

            
#reduced_women['my_categories']=reduced_women['categories'].apply(cat_def)
#reduced_women
            


#reduced_women['categories'].apply(cat_def)

# %%
reduced_women['my_categories']=reduced_women['categories'].apply(cat_def)

# %%
reduced_women = reduced_women[reduced_women['my_categories'].isnull()==False]
reduced_women
# Out:
#           brand                                         categories  \
# 27     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 28     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 29     SKECHERS  Sneakers,Womens Shoes,Clothing,Work Safety Clo...
# 30     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# 31     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# ...         ...                                                ...
# 33757  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33758  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33759  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33760  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33761  Skechers                       Shoes,Slip-ons,Women's Shoes
#
#        prices.amountMax  prices.amountMin prices.currency       colors  \
# 27                85.00             85.00             USD        Black
# 28                85.00             85.00             USD        Black
# 29                75.00             75.00             USD        Black
# 30                49.99             44.99             USD  Taupe,White
# 31                49.99             49.99             USD  Taupe,White
# ...                 ...               ...             ...          ...
# 33757             44.36             44.36             USD          NaN
# 33758             44.36             44.36             USD          NaN
# 33759             44.36             44.36             USD          NaN
# 33760             44.36             44.36             USD          NaN
# 33761             44.36             44.36             USD          NaN
#
#                                                     name  \
# 27     Skechers Women's Skech-Air Lingle Black Memory...
# 28     Skechers Women's Skech-Air Lingle Black Memory...
# 29     76580 W Wide Width Black Skechers Shoe New Wom...
# 30     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# 31     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# ...                                                  ...
# 33757  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33758  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33759  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33760  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33761  Women's Skechers Relaxed Fit Breathe Easy Fait...
#
#                                 sizes features  reviews  medium_price  \
# 27      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN         85.00
# 28      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN         85.00
# 29     5,5.5,6,6.5,7.5,9.5,9.5 WIDE,7      NaN      NaN         75.00
# 30                    5,6,7,8,9,10,11      NaN      NaN         47.49
# 31                    5,6,7,8,9,10,11      NaN      NaN         49.99
# ...                               ...      ...      ...           ...
# 33757                             NaN      NaN      NaN         44.36
# 33758                             NaN      NaN      NaN         44.36
# 33759                             NaN      NaN      NaN         44.36
# 33760                             NaN      NaN      NaN         44.36
# 33761                             NaN      NaN      NaN         44.36
#
#       my_categories
# 27         Sneakers
# 28         Sneakers
# 29         Sneakers
# 30         Skechers
# 31         Skechers
# ...             ...
# 33757      Slip-ons
# 33758      Slip-ons
# 33759      Slip-ons
# 33760      Slip-ons
# 33761      Slip-ons
#
# [7786 rows x 12 columns]

# %%
reduced_women['my_categories'].value_counts()

# %% [markdown]
# Raggruppo su categorie più specifiche: Sneakers (rifermiento ai marchi). Sports,

# %%
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Adidas', 'Urban')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Nike', 'Urban')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace("Womens' Athletic Shoes", 'Athletic')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Slip-ons','Urban')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Gravity Defyer', 'Athletic')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Team Sports','Athletic')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Walking Shoes', 'Outdoor')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Basketball', 'Athletic')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Trendsetter', 'Urban')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Skechers', 'Urban')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Running', 'Athletic')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Sports', 'Athletic')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Sneakers','Urban')
reduced_women['my_categories']= reduced_women['my_categories'].str.replace('Running','Athletic')
reduced_women
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           brand                                         categories  \
# 27     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 28     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 29     SKECHERS  Sneakers,Womens Shoes,Clothing,Work Safety Clo...
# 30     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# 31     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# ...         ...                                                ...
# 33757  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33758  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33759  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33760  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33761  Skechers                       Shoes,Slip-ons,Women's Shoes
#
#        prices.amountMax  prices.amountMin prices.currency       colors  \
# 27                85.00             85.00             USD        Black
# 28                85.00             85.00             USD        Black
# 29                75.00             75.00             USD        Black
# 30                49.99             44.99             USD  Taupe,White
# 31                49.99             49.99             USD  Taupe,White
# ...                 ...               ...             ...          ...
# 33757             44.36             44.36             USD          NaN
# 33758             44.36             44.36             USD          NaN
# 33759             44.36             44.36             USD          NaN
# 33760             44.36             44.36             USD          NaN
# 33761             44.36             44.36             USD          NaN
#
#                                                     name  \
# 27     Skechers Women's Skech-Air Lingle Black Memory...
# 28     Skechers Women's Skech-Air Lingle Black Memory...
# 29     76580 W Wide Width Black Skechers Shoe New Wom...
# 30     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# 31     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# ...                                                  ...
# 33757  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33758  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33759  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33760  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33761  Women's Skechers Relaxed Fit Breathe Easy Fait...
#
#                                 sizes features  reviews  medium_price  \
# 27      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN         85.00
# 28      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN         85.00
# 29     5,5.5,6,6.5,7.5,9.5,9.5 WIDE,7      NaN      NaN         75.00
# 30                    5,6,7,8,9,10,11      NaN      NaN         47.49
# 31                    5,6,7,8,9,10,11      NaN      NaN         49.99
# ...                               ...      ...      ...           ...
# 33757                             NaN      NaN      NaN         44.36
# 33758                             NaN      NaN      NaN         44.36
# 33759                             NaN      NaN      NaN         44.36
# 33760                             NaN      NaN      NaN         44.36
# 33761                             NaN      NaN      NaN         44.36
#
#       my_categories
# 27            Urban
# 28            Urban
# 29            Urban
# 30            Urban
# 31            Urban
# ...             ...
# 33757         Urban
# 33758         Urban
# 33759         Urban
# 33760         Urban
# 33761         Urban
#
# [7786 rows x 12 columns]

# %%
reduced_women['my_categories'].value_counts()

# %%
import json
import math
import sys

# %%
def extract_material(features_json):
    # [{"key":"Material","value":["Suede"]},{"key":"Gender","value":["Men"]},{"key":"Color","value":["Beige"]},{"key":"Model","value":["M254TNN"]},{"key":"Manufacturer Part Number","value":["M254TNN"]},{"key":"Brand","value":["New Balance Numeric"]},{"key":"Age Group","value":["Adult"]}]    
    try:
        if (type(features_json) == float):
            return None
        
        if (type(features_json) != str):
            print( f"WARN not a string but a {type(features_json)} {features_json}" )
            return None
        
        features_json = features_json.replace("\\\\", "\\")
        kvs = json.loads(features_json)
        for kv in kvs:
            if(kv["key"] == "Material"):
                return kv["value"][0]
            
        return None
    except:
        err_type, err_value, err_traceback = sys.exc_info()
        print( f"WARN '{err_type}' '{err_value}' parsing {features_json}" )
        return None

# %%
reduced_women['material']=reduced_women['features'].apply(extract_material)
reduced_women
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           brand                                         categories  \
# 27     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 28     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 29     SKECHERS  Sneakers,Womens Shoes,Clothing,Work Safety Clo...
# 30     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# 31     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# ...         ...                                                ...
# 33757  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33758  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33759  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33760  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33761  Skechers                       Shoes,Slip-ons,Women's Shoes
#
#        prices.amountMax  prices.amountMin prices.currency       colors  \
# 27                85.00             85.00             USD        Black
# 28                85.00             85.00             USD        Black
# 29                75.00             75.00             USD        Black
# 30                49.99             44.99             USD  Taupe,White
# 31                49.99             49.99             USD  Taupe,White
# ...                 ...               ...             ...          ...
# 33757             44.36             44.36             USD          NaN
# 33758             44.36             44.36             USD          NaN
# 33759             44.36             44.36             USD          NaN
# 33760             44.36             44.36             USD          NaN
# 33761             44.36             44.36             USD          NaN
#
#                                                     name  \
# 27     Skechers Women's Skech-Air Lingle Black Memory...
# 28     Skechers Women's Skech-Air Lingle Black Memory...
# 29     76580 W Wide Width Black Skechers Shoe New Wom...
# 30     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# 31     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# ...                                                  ...
# 33757  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33758  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33759  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33760  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33761  Women's Skechers Relaxed Fit Breathe Easy Fait...
#
#                                 sizes features  reviews  medium_price  \
# 27      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN         85.00
# 28      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN         85.00
# 29     5,5.5,6,6.5,7.5,9.5,9.5 WIDE,7      NaN      NaN         75.00
# 30                    5,6,7,8,9,10,11      NaN      NaN         47.49
# 31                    5,6,7,8,9,10,11      NaN      NaN         49.99
# ...                               ...      ...      ...           ...
# 33757                             NaN      NaN      NaN         44.36
# 33758                             NaN      NaN      NaN         44.36
# 33759                             NaN      NaN      NaN         44.36
# 33760                             NaN      NaN      NaN         44.36
# 33761                             NaN      NaN      NaN         44.36
#
#       my_categories material
# 27            Urban     None
# 28            Urban     None
# 29            Urban     None
# 30            Urban     None
# 31            Urban     None
# ...             ...      ...
# 33757         Urban     None
# 33758         Urban     None
# 33759         Urban     None
# 33760         Urban     None
# 33761         Urban     None
#
# [7786 rows x 13 columns]

# %%
reduced_women = reduced_women[reduced_women['material'].isnull()==False]

# %%
rows = reduced_women['material'].unique()
#print(rows)
s = set()
for row in rows:
    #print("-- " + row)
    categories = row.split(",")
    for category in categories:
        ##print("---- " + category)
        s.add(category)

print(s)
# Out:
# {'MESH', 'Flyknit', 'polyester', 'Unknown', 'rubber', '.', 'Man Made/Fabric', 'Patent-Leather', 'Textile', 'Wool', 'Leather', 'Cork', 'Suede', 'Glitter', 'Fabric/Man Made', 'Synthetic', 'Man Made', 'Canvas/Suede', 'Leather-And-Synthetic', 'No Material Tag', 'Synthetic/Nylon/Rubber', 'Synthetic-And-Leather', 'Leather/Lorica', 'Synthetic Leather', 'Canvas', 'Synthetic/Mesh', 'Synthetic-And-Mesh', 'canvas', 'Leather/Man Made', 'Mesh', 'leather-and-fabric', 'Lightweight Fabric/Foam', 'Synthetic/Nylon', 'Faux Suede', 'leather', 'Synthetic Upper/Rubber Sole'}

# %%
mat_to_save = ['rubber','canvas','Suede','Synthetic','Textile','Leather','Flyknit','Wool','Mesh','polyester','Cork','Man Made','leather','MESH','Synthetic-And-Mesh','Synthetic/Nylon/Rubber','Patent-Leather','Synthetic/Mesh','Synthetic Upper/Rubber Sole','Faux Suede','Synthetic Leather','Canvas/Suede']

# %%
def mat_def(x):
    for mat in mat_to_save:
        if mat in x :
            return (mat)
    return 'altro'

   

            
reduced_women['my_material']=reduced_women['material'].apply(mat_def)
reduced_women
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#              brand                                         categories  \
# 161          ASICS                             Athletic,Women's Shoes
# 162          ASICS                             Athletic,Women's Shoes
# 323    New Balance                             Women's Shoes,Athletic
# 392           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# 393           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# ...            ...                                                ...
# 24589       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24590       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24591       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24691     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
# 24692     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 161              159.99            159.99             USD
# 162               99.99             99.99             USD
# 323               44.99             44.99             USD
# 392               39.66             39.66             USD
# 393               35.99             35.99             USD
# ...                 ...               ...             ...
# 24589             56.90             56.90             USD
# 24590             56.90             56.90             USD
# 24591             56.43             56.43             USD
# 24691             69.90             69.90             USD
# 24692             65.00             65.00             USD
#
#                          colors  \
# 161    IRIDESCENTPINKCAPRI BLUE
# 162    IRIDESCENTPINKCAPRI BLUE
# 323                       White
# 392                 Multi-Color
# 393                 Multi-Color
# ...                         ...
# 24589                     Brown
# 24590                     Brown
# 24591                     Brown
# 24691          Black,BlackBlack
# 24692          Black,BlackBlack
#
#                                                     name sizes  \
# 161    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 162    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 323      New Balance Ww496 Women Us 9 White Walking Shoe     9
# 392    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# 393    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# ...                                                  ...   ...
# 24589  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24590  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24591  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24691  Converse Women's Chuck Taylor All Star Madison...   NaN
# 24692  Converse Women's Chuck Taylor All Star Madison...   NaN
#
#                                                 features  reviews  \
# 161    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 162    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 323    [{"key":"Style","value":["Walking"]},{"key":"E...      NaN
# 392    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# 393    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# ...                                                  ...      ...
# 24589  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24590  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24591  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24691  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24692  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
#
#        medium_price my_categories   material my_material
# 161          159.99      Athletic       MESH        MESH
# 162           99.99      Athletic       MESH        MESH
# 323           44.99      Athletic  Synthetic   Synthetic
# 392           39.66      Athletic    Textile     Textile
# 393           35.99      Athletic    Textile     Textile
# ...             ...           ...        ...         ...
# 24589         56.90      Athletic    Leather     Leather
# 24590         56.90      Athletic    Leather     Leather
# 24591         56.43      Athletic    Leather     Leather
# 24691         69.90      Athletic    Leather     Leather
# 24692         65.00      Athletic    Leather     Leather
#
# [678 rows x 14 columns]

# %%
reduced_women['my_material'].value_counts()
# Out:
# Synthetic    203
# Mesh         200
# Leather       98
# altro         59
# Textile       49
# Suede         35
# polyester      7
# Flyknit        7
# Wool           6
# Man Made       4
# leather        3
# rubber         3
# MESH           2
# canvas         1
# Cork           1
# Name: my_material, dtype: int64

# %%
reduced_women['my_material']  = reduced_women['my_material'].str.replace('MESH', 'Mesh')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('leather', 'Leather')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('polyester','Synthetic')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('Man Made', 'Synthetic')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('Sinthetic','Synthetic')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('canvas', 'Textile')
reduced_women['my_material']  = reduced_women['my_material'].str.replace( 'Cork', 'Textile')
reduced_women['my_material']  = reduced_women['my_material'].str.replace( 'Wool','Textile')
reduced_women
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              brand                                         categories  \
# 161          ASICS                             Athletic,Women's Shoes
# 162          ASICS                             Athletic,Women's Shoes
# 323    New Balance                             Women's Shoes,Athletic
# 392           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# 393           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# ...            ...                                                ...
# 24589       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24590       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24591       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24691     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
# 24692     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 161              159.99            159.99             USD
# 162               99.99             99.99             USD
# 323               44.99             44.99             USD
# 392               39.66             39.66             USD
# 393               35.99             35.99             USD
# ...                 ...               ...             ...
# 24589             56.90             56.90             USD
# 24590             56.90             56.90             USD
# 24591             56.43             56.43             USD
# 24691             69.90             69.90             USD
# 24692             65.00             65.00             USD
#
#                          colors  \
# 161    IRIDESCENTPINKCAPRI BLUE
# 162    IRIDESCENTPINKCAPRI BLUE
# 323                       White
# 392                 Multi-Color
# 393                 Multi-Color
# ...                         ...
# 24589                     Brown
# 24590                     Brown
# 24591                     Brown
# 24691          Black,BlackBlack
# 24692          Black,BlackBlack
#
#                                                     name sizes  \
# 161    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 162    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 323      New Balance Ww496 Women Us 9 White Walking Shoe     9
# 392    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# 393    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# ...                                                  ...   ...
# 24589  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24590  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24591  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24691  Converse Women's Chuck Taylor All Star Madison...   NaN
# 24692  Converse Women's Chuck Taylor All Star Madison...   NaN
#
#                                                 features  reviews  \
# 161    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 162    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 323    [{"key":"Style","value":["Walking"]},{"key":"E...      NaN
# 392    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# 393    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# ...                                                  ...      ...
# 24589  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24590  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24591  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24691  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24692  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
#
#        medium_price my_categories   material my_material
# 161          159.99      Athletic       MESH        Mesh
# 162           99.99      Athletic       MESH        Mesh
# 323           44.99      Athletic  Synthetic   Synthetic
# 392           39.66      Athletic    Textile     Textile
# 393           35.99      Athletic    Textile     Textile
# ...             ...           ...        ...         ...
# 24589         56.90      Athletic    Leather     Leather
# 24590         56.90      Athletic    Leather     Leather
# 24591         56.43      Athletic    Leather     Leather
# 24691         69.90      Athletic    Leather     Leather
# 24692         65.00      Athletic    Leather     Leather
#
# [678 rows x 14 columns]

# %%
reduced_women['my_material'].value_counts()

# %%
reduced_women=reduced_women[reduced_women["colors"].isnull()==False]
reduced_women

# %%
reduced_women['colors']  = reduced_women['colors'].str.replace('Multi-Colored', 'Multicolor')
reduced_women['colors']  = reduced_women['colors'].str.replace('Multi-Color', 'Multicolor')
reduced_women['colors']  = reduced_women['colors'].str.replace('Tea', 'Orange')
reduced_women['colors']  = reduced_women['colors'].str.replace('Oxfordblood', 'Red')
reduced_women['colors']  = reduced_women['colors'].str.replace('Vivid Sulfur', 'Black')
reduced_women['colors']  = reduced_women['colors'].str.replace('BLK', 'Black')
reduced_women['colors']  = reduced_women['colors'].str.replace('Sandstone', 'Natural')
reduced_women['colors']  = reduced_women['colors'].str.replace('OcgWhtMpt', 'White')
reduced_women['colors']  = reduced_women['colors'].str.replace('Indigo Tropical', 'Blue')
reduced_women['colors']  = reduced_women['colors'].str.replace('Fuchsia', 'Purple')
reduced_women['colors']  = reduced_women['colors'].str.replace('Pure PlatinumBlackHotLava', 'Black')
reduced_women['colors']  = reduced_women['colors'].str.replace('Linen', 'Natural')
reduced_women['colors']  = reduced_women['colors'].str.replace('Beige', 'Natural')
reduced_women['colors']  = reduced_women['colors'].str.replace('VebWhtMed', 'White')
reduced_women['colors']  = reduced_women['colors'].str.replace('BlackBright Cherry SuedeTextile', 'Red')
reduced_women['colors']  = reduced_women['colors'].str.replace('NtrlBlcdblc','Black')
reduced_women['colors']  = reduced_women['colors'].str.replace('Anthracite','Grey')
reduced_women['colors']  = reduced_women['colors'].str.replace('Tan', 'Brown')
reduced_women['colors']  = reduced_women['colors'].str.replace('Hypr Orng', 'Orange')
reduced_women['colors']  = reduced_women['colors'].str.replace('Bright CrimsonDeep GarnetWht','Red')
reduced_women['colors']  = reduced_women['colors'].str.replace('Gray','Grey')
reduced_women['colors']  = reduced_women['colors'].str.replace('Coffee', 'Brown')
reduced_women['colors']  = reduced_women['colors'].str.replace('Citron','Yellow')
reduced_women['colors']  = reduced_women['colors'].str.replace('Oranges','Orange')
reduced_women['colors']  = reduced_women['colors'].str.replace('Slime', 'Multicolor')
reduced_women['colors']  = reduced_women['colors'].str.replace('IRIDESCENTPINKCAPRI BLUE','Multicolor')
reduced_women['colors']  = reduced_women['colors'].str.replace('Bleached LilacBleached Lilac','Purple')
reduced_women

# %%
rows = reduced_women['colors'].unique()
#print(rows)
s = set()
for row in rows:
    #print("-- " + row)
    categories = row.split(",")
    for category in categories:
        ##print("---- " + category)
        s.add(category)

print(s)

# %%
col_to_save = ['Black', 'Pink', 'Red','White', 'Silver', 'Blue', 'Grey', 'Multicolor', 'Purple', 'Yellow','Green','Gold', 'Brown','Natural']

# %%
def col_def(x):
    for col in col_to_save:
        if col in x :
            return (col)

reduced_women['my_colors']=reduced_women['colors'].apply(col_def)
reduced_women

# %%
reduced_women=reduced_women[reduced_women['my_colors'].isnull()==False]
reduced_women

# %%
women_price = reduced_women[['my_categories', 'my_material','medium_price']]
#women_price['medium_price'] = women_price['medium_price'].round()
women_price
# Out:
#       my_categories my_material  medium_price
# 161        Athletic        Mesh        159.99
# 162        Athletic        Mesh         99.99
# 323        Athletic   Synthetic         44.99
# 392        Athletic     Textile         39.66
# 393        Athletic     Textile         35.99
# ...             ...         ...           ...
# 24589      Athletic     Leather         56.90
# 24590      Athletic     Leather         56.90
# 24591      Athletic     Leather         56.43
# 24691      Athletic     Leather         69.90
# 24692      Athletic     Leather         65.00
#
# [678 rows x 3 columns]

# %%
women_price = pd.get_dummies(women_price, columns = ['my_categories', 'my_material'])
women_price
# Out:
#        medium_price  my_categories_Athletic  my_categories_Outdoor  \
# 161          159.99                       1                      0
# 162           99.99                       1                      0
# 323           44.99                       1                      0
# 392           39.66                       1                      0
# 393           35.99                       1                      0
# ...             ...                     ...                    ...
# 24589         56.90                       1                      0
# 24590         56.90                       1                      0
# 24591         56.43                       1                      0
# 24691         69.90                       1                      0
# 24692         65.00                       1                      0
#
#        my_categories_Urban  my_material_Flyknit  my_material_Leather  \
# 161                      0                    0                    0
# 162                      0                    0                    0
# 323                      0                    0                    0
# 392                      0                    0                    0
# 393                      0                    0                    0
# ...                    ...                  ...                  ...
# 24589                    0                    0                    1
# 24590                    0                    0                    1
# 24591                    0                    0                    1
# 24691                    0                    0                    1
# 24692                    0                    0                    1
#
#        my_material_Mesh  my_material_Suede  my_material_Synthetic  \
# 161                   1                  0                      0
# 162                   1                  0                      0
# 323                   0                  0                      1
# 392                   0                  0                      0
# 393                   0                  0                      0
# ...                 ...                ...                    ...
# 24589                 0                  0                      0
# 24590                 0                  0                      0
# 24591                 0                  0                      0
# 24691                 0                  0                      0
# 24692                 0                  0                      0
#
#        my_material_Textile  my_material_altro  my_material_rubber
# 161                      0                  0                   0
# 162                      0                  0                   0
# 323                      0                  0                   0
# 392                      1                  0                   0
# 393                      1                  0                   0
# ...                    ...                ...                 ...
# 24589                    0                  0                   0
# 24590                    0                  0                   0
# 24591                    0                  0                   0
# 24691                    0                  0                   0
# 24692                    0                  0                   0
#
# [678 rows x 12 columns]

# %%
#from sklearn.tree  import make_regression
from sklearn.tree import DecisionTreeRegressor


X = women_price.drop(['medium_price'], axis = 1)
y = women_price.iloc[:,0]

# %%
X
# Out:
#        my_categories_Athletic  my_categories_Outdoor  my_categories_Urban  \
# 161                         1                      0                    0
# 162                         1                      0                    0
# 323                         1                      0                    0
# 392                         1                      0                    0
# 393                         1                      0                    0
# ...                       ...                    ...                  ...
# 24589                       1                      0                    0
# 24590                       1                      0                    0
# 24591                       1                      0                    0
# 24691                       1                      0                    0
# 24692                       1                      0                    0
#
#        my_material_Flyknit  my_material_Leather  my_material_Mesh  \
# 161                      0                    0                 1
# 162                      0                    0                 1
# 323                      0                    0                 0
# 392                      0                    0                 0
# 393                      0                    0                 0
# ...                    ...                  ...               ...
# 24589                    0                    1                 0
# 24590                    0                    1                 0
# 24591                    0                    1                 0
# 24691                    0                    1                 0
# 24692                    0                    1                 0
#
#        my_material_Suede  my_material_Synthetic  my_material_Textile  \
# 161                    0                      0                    0
# 162                    0                      0                    0
# 323                    0                      1                    0
# 392                    0                      0                    1
# 393                    0                      0                    1
# ...                  ...                    ...                  ...
# 24589                  0                      0                    0
# 24590                  0                      0                    0
# 24591                  0                      0                    0
# 24691                  0                      0                    0
# 24692                  0                      0                    0
#
#        my_material_altro  my_material_rubber
# 161                    0                   0
# 162                    0                   0
# 323                    0                   0
# 392                    0                   0
# 393                    0                   0
# ...                  ...                 ...
# 24589                  0                   0
# 24590                  0                   0
# 24591                  0                   0
# 24691                  0                   0
# 24692                  0                   0
#
# [678 rows x 11 columns]

# %%
y
# Out:
# 161      159.99
# 162       99.99
# 323       44.99
# 392       39.66
# 393       35.99
#           ...
# 24589     56.90
# 24590     56.90
# 24591     56.43
# 24691     69.90
# 24692     65.00
# Name: medium_price, Length: 678, dtype: float64

# %%
from sklearn.model_selection import train_test_split

#Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=3)

# %%
tree_reg = DecisionTreeRegressor(max_depth=8)
tree_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=8,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=[80,80])
tree.plot_tree(tree_reg, 
               class_names= True,
               filled=True, 
              )
plt.show()
