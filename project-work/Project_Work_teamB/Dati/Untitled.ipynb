# %%
# %matplotlib inline
import pandas as pd
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import golden

# %%
man_shoes = pd.read_csv("C:/Users/Amministratore/corso-ifoa-machine-learning/project-work/dataset/man-shoes/Datafiniti_Mens_Shoe_Prices.csv", error_bad_lines=False)
# Out:
# b'Skipping line 251: expected 48 fields, saw 49\nSkipping line 444: expected 48 fields, saw 50\nSkipping line 847: expected 48 fields, saw 49\nSkipping line 848: expected 48 fields, saw 49\nSkipping line 1018: expected 48 fields, saw 49\nSkipping line 1575: expected 48 fields, saw 51\nSkipping line 2133: expected 48 fields, saw 49\nSkipping line 2922: expected 48 fields, saw 51\nSkipping line 3777: expected 48 fields, saw 51\nSkipping line 4057: expected 48 fields, saw 49\nSkipping line 4239: expected 48 fields, saw 49\nSkipping line 4240: expected 48 fields, saw 49\nSkipping line 4384: expected 48 fields, saw 49\nSkipping line 4385: expected 48 fields, saw 49\nSkipping line 5388: expected 48 fields, saw 49\nSkipping line 5480: expected 48 fields, saw 49\nSkipping line 5481: expected 48 fields, saw 49\nSkipping line 5907: expected 48 fields, saw 50\nSkipping line 5908: expected 48 fields, saw 50\nSkipping line 6600: expected 48 fields, saw 49\nSkipping line 6601: expected 48 fields, 
# ...

# %%
pd.set_option("display.max_columns", 50)
pd.set_option("max_rows", 500)

man_shoes
# Out:
#                          id asins                brand  \
# 0      AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 1      AVpfHrJ6ilAPnD_xVXOI   NaN                Josmo
# 2      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 3      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# 4      AVpfHsWP1cnluZ0-eVZ7   NaN  SERVUS BY HONEYWELL
# ...                     ...   ...                  ...
# 19310  AVpfdSjlilAPnD_xcGPm   NaN           Xray, XRay
# 19311  AVpf3bFWilAPnD_xjrQ2   NaN                 Fila
# 19312  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
# 19313  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
# 19314  AVpf0fJXLJeJML43EVe9   NaN          Seek Optics
#
#                                               categories colors  count  \
# 0             Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 1             Clothing,Shoes,Men's Shoes,All Men's Shoes    NaN    NaN
# 2             All Men's Shoes,Shoes,Men's Shoes,Clothing    NaN    NaN
# ...

# %%
rows = man_shoes["categories"].unique()

s = set ()



for row in rows:
    #print("-- " + row)
    categories = row.split(",")
    for category in categories:
        ##print("---- " + category)
        s.add(category)
           

print(s)
# Out:
# {'Novelty', "Men's Hats", 'Enduro', 'Cotton', 'Engines & Engine Parts', 'Classics', 'Outdoor Equipment', 'By Recipient', 'See more Bostonian Wendell Mens Leather Oxfords Shoes 1...', 'Outdoor Tools & Supplies', 'Tools', 'Men%27s Shoes', ' Accessories', 'Medical', 'Chukkas', 'See more Deezone Aluminum RFID Blocking Credit Card Hol...', 'See more Nike Vapor Carbon 2014 Elite TD Mens Football ...', "Young Men's Activewear", 'See more Mens TPU X Performance Bowling Shoes with Inte...', 'Bath', 'Water Sports', 'Golf Clothing', 'Outerwear Coats & Jackets', 'Boxing', "See more American Eagle Outfitters Men's Original Strai...", 'sports & outdoors', 'New Arrivals', 'Sandals & Flip-Flops', "Men's Cleats", 'Home & Kitchen', 'Protective Workwear', 'See more Levis Jeans 560 Comfort Loose Fit Tapered Leg ...', 'Lab', 'Patio', 'See more Riggs Workwear Wrangler Mens Jeans 36x36 Carpe...', 'Office Safety & Security', 'Golf Gloves', "Women's Work Gloves", ' Shoes', 'Intimates & Sleepwear', 'Mid-Calf 
# ...

# %%
    
to_save = ['Sneakers','Sneaker','sneaker', 'sneakers', "Driving Shoes", 'Running', "Men's Jackets & Outerwear",'Boat Shoes',
               'Family Recreation', 'Prada Sport','Sports & Fitness',  'Hiking', 'Cycling', 'Other Slip-Ons',  
               "Men's Sneakers & Athletic Shoes",'Fitness', 'Fitness & Cross-Training', 'Basketball',  'Athletic Socks',  
               'Walking Shoes', 'Racquet Sports', 'Running Shoes', 'Fashion Sneakers', 
               'Camping & Hiking', 'sports', 'Slip-ons',  'Skateboarding', 'Sneakers & Athletic Shoes', 
               'Team Sports', 'Sports', 'Sports & Outdoors', ' Skate & Street', 
               'Athletic', 'Outdoor', 'Outdoor Activities',  'Active & Performance', 'Active', 'Tennis',
               'Fitness & Sports', 'Exercise & Fitness', 'Hiking & Trekking', "Men's Casual Shoes",
               'Camping', 'Baseball', 'adidas', 'Active', 'Lacrosse', 'Nike ', 'Puma', 'adidas', 'Training', 
               'Trainers', 'Running', 'Under Armour',  ]






to_save_work = ["Big & Tall Workwear", "Construction Workwear", "Men's Work Socks & Underwear",  "Men's Workwear & Uniforms", 
               'Craftsman Tools',  "Men's Work Gloves",  'Safety Apparel', 'Safety Equipment & Gear', 'Power Tools', 
               'Work Boots', 'Big & Tall Overalls', 'Construction Overalls', 'Office Safety & Security', 'Medical', 'Work Slip-Ons',
                "Men's Work Outerwear",' Work & Safety', "Men's Work Shoes & Boots", 'Craftsman Workwear & Work Boots',
               "Men's Work & Safety Shoes", 'Safety & Shop Gear', 'Industrial & Construction', 'Workwear & Uniforms', 
               'Work Safety Clothing and Equipment', 'Professional & Trade Workwear']






def cat_def_sneakers(x):
    for i in to_save:
        if i in x : 
            return (i)

        
def cat_def_work(x):
    for i in to_save_work:
        if i in x : 
            return (i)

# %%
man_shoes_sneakers = pd.DataFrame ()

man_shoes_sneakers["categoria_sneakers"] = man_shoes["categories"].apply( cat_def_sneakers )
man_shoes_sneakers["categoria_work"] = man_shoes["categories"].apply( cat_def_work )

man_shoes_sneakers
# Out:
#       categoria_sneakers categoria_work
# 0                   None           None
# 1                   None           None
# 2                   None           None
# 3                   None           None
# 4                   None           None
# ...                  ...            ...
# 19310               None           None
# 19311               None           None
# 19312               None           None
# 19313               None           None
# 19314               None           None
#
# [19315 rows x 2 columns]

# %%
man_shoes_sneakers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19315 entries, 0 to 19314
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   macro_categoria  4877 non-null   object
# dtypes: object(1)
# memory usage: 151.0+ KB

# %%
man_shoes_sneakers["macro_categoria"].value_counts()
# Out:
# Men's Casual Shoes           1420
# Athletic                     1021
# Team Sports                   718
# Sneakers                      354
# Running                       279
# Sports                        225
# Active                        176
# Cycling                       126
# Basketball                     83
# Outdoor                        63
# Skateboarding                  57
# Fitness                        45
# Hiking                         41
# Baseball                       34
# Athletic Socks                 31
# Sports & Fitness               29
# Active & Performance           29
# Men's Jackets & Outerwear      28
#  Skate & Street                25
# Prada Sport                    16
# Walking Shoes                  15
# Racquet Sports                 14
# Boat Shoes                      9
# sports                          9
# Other Slip-Ons                  9
# Nike                            7
# Family Recreation               5
# ...

# %%
man_shoes["categories"].unique()
# Out:
# array(["Clothing,Shoes,Men's Shoes,All Men's Shoes",
#        "All Men's Shoes,Shoes,Men's Shoes,Clothing",
#        "Men's Casual Shoes,Shoes,Men's Shoes,Clothing", ...,
#        "Clothing,Shoes,Women's Shoes,Women's Casual Shoes,All Men's Shoes,Men's Shoes",
#        "Clothing, Shoes & Accessories,Men's Clothing,Jeans,See more Men's Levi's 505 Straight Leg Regular Fit Jean...",
#        'Sports,Clothing, Shoes & Jewelry,Men,Clothing,Jackets & Coats,Active & Performance,Shells'],
#       dtype=object)

# %%
man_shoes_sneakers["categoria_work"].value_counts()
# Out:
# Men's Workwear & Uniforms             895
#  Work & Safety                        488
# Men's Work Shoes & Boots              172
# Safety Apparel                         38
# Safety Equipment & Gear                28
# Work Boots                             24
# Men's Work Socks & Underwear           15
# Medical                                 7
# Big & Tall Workwear                     5
# Work Safety Clothing and Equipment      5
# Industrial & Construction               4
# Work Slip-Ons                           3
# Craftsman Tools                         2
# Power Tools                             1
# Name: categoria_work, dtype: int64

# %%
for i in man_shoes["prices.amountMin"].astype(float):
    for j in man_shoes["prices.amountMax"].astype(float):
        y = (i+j / 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-1736f5dc6fd9> in <module>
# ----> 1 for i in man_shoes["prices.amountMin"].astype(float):
#       2     for j in man_shoes["prices.amountMax"].astype(float):
#       3         y = (i+j / 2)
#       4
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# ...
