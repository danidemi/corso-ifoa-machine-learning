# %%
import pandas as pd


women_shoes = pd.concat(map(pd.read_csv, ['Datafiniti_Womens_Shoes.csv', 'Datafiniti_Womens_Shoes_Jun19.csv', '7210_1.csv']))
women_shoes
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (13,16,18,22,24,32,33,40,41,47,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                          id             dateAdded           dateUpdated  \
# 0      AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z
# 1      AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z
# 2      AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z
# 3      AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z
# 4      AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z
# ...                     ...                   ...                   ...
# 33796  AVsUxZClnnc1JgDc4Mev  2017-03-28T11:55:43Z  2017-03-28T11:55:43Z
# 33797  AVsUyEcaU2_QcyX9Pb4g  2017-03-28T11:58:41Z  2017-03-28T11:58:41Z
# 33798  AVsUyEcaU2_QcyX9Pb4g  2017-03-28T11:58:41Z  2017-03-28T11:58:41Z
# 33799  AVticmzVnnc1JgDc5Uym  2017-04-12T13:55:17Z  2017-04-13T20:44:29Z
# 33800  AVtidDQ-nnc1JgDc5U4Q  2017-04-12T13:57:14Z  2017-04-13T20:41:27Z
#
#             asins            brand  \
# 0             NaN      Naturalizer
# 1             NaN         MUK LUKS
# 2             NaN         MUK LUKS
# 3             NaN         MUK LUKS
# 4             NaN         MUK LUKS
# ...           ...              ...
# 33796         NaN           Novica
# 33797         NaN           Novica
# 33798         NaN           Novica
# 33799  B06XZJTJBT  City Classified
# 33800  B0188Y3WM2           Vionic
#
#                                               categories primaryCategories  \
# 0      Clothing,Shoes,Women's Shoes,All Women's Shoes...             Shoes
# 1      Clothing,Shoes,Women's Shoes,Women's Casual Sh...             Shoes
# 2      Clothing,Shoes,Women's Shoes,Women's Casual Sh...             Shoes
# 3      Clothing,Shoes,Women's Shoes,All Women's Shoes...       Shoes,Shoes
# 4      Clothing,Shoes,Women's Shoes,All Women's Shoes...             Shoes
# ...                                                  ...               ...
# 33796            Access.,Clothing,Shoes,Women's Clothing               NaN
# 33797            Access.,Clothing,Shoes,Women's Clothing               NaN
# 33798            Access.,Clothing,Shoes,Women's Clothing               NaN
# 33799                        Clothing,,Women,Shoes,Pumps               NaN
# 33800                      Women,Shoes,Sandals,Clothing,               NaN
#
#                                colors                 dimension           ean  \
# 0      Silver,Cream Watercolor Floral                       NaN           NaN
# 1                                Grey                       NaN  3.397705e+10
# 2                                Grey                       NaN  3.397705e+10
# 3                               Black  6.0 in x 6.0 in x 1.0 in  3.397705e+10
# 4                                Grey  6.0 in x 6.0 in x 1.0 in  3.397705e+10
# ...                               ...                       ...           ...
# 33796                            Blue                       NaN           NaN
# 33797                             Red             30 in x 31 in           NaN
# 33798                             Red             30 in x 31 in           NaN
# 33799                             NaN                       NaN           NaN
# 33800                             NaN                       NaN           NaN
#
#        ... prices.warranty                                         quantities  \
# 0      ...             NaN                                                NaN
# 1      ...             NaN                                                NaN
# 2      ...             NaN                                                NaN
# 3      ...             NaN                                                NaN
# 4      ...             NaN                                                NaN
# ...    ...             ...                                                ...
# 33796  ...             NaN  [{"dateSeen":["2017-03-26T10:04:21.331Z"],"sou...
# 33797  ...             NaN  [{"dateSeen":["2017-03-26T18:48:59.335Z"],"sou...
# 33798  ...             NaN  [{"dateSeen":["2017-03-26T18:48:59.335Z"],"sou...
# 33799  ...             NaN                                                NaN
# 33800  ...             NaN                                                NaN
#
#       reviews                                               skus vin  \
# 0         NaN                                                NaN NaN
# 1         NaN                                                NaN NaN
# 2         NaN                                                NaN NaN
# 3         NaN                                                NaN NaN
# 4         NaN                                                NaN NaN
# ...       ...                                                ...  ..
# 33796     NaN  [{"sourceURLs":["https://www.overstock.com/Wor... NaN
# 33797     NaN  [{"sourceURLs":["https://www.overstock.com/Wor... NaN
# 33798     NaN  [{"sourceURLs":["https://www.overstock.com/Wor... NaN
# 33799     NaN                                                NaN NaN
# 33800     NaN                                                NaN NaN
#
#        websiteIDs  Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51
# 0             NaN          NaN         NaN         NaN         NaN
# 1             NaN          NaN         NaN         NaN         NaN
# 2             NaN          NaN         NaN         NaN         NaN
# 3             NaN          NaN         NaN         NaN         NaN
# 4             NaN          NaN         NaN         NaN         NaN
# ...           ...          ...         ...         ...         ...
# 33796         NaN          NaN         NaN         NaN         NaN
# 33797         NaN          NaN         NaN         NaN         NaN
# 33798         NaN          NaN         NaN         NaN         NaN
# 33799         NaN          NaN         NaN         NaN         NaN
# 33800         NaN          NaN         NaN         NaN         NaN
#
# [53801 rows x 54 columns]

# %%
women_shoes.info()

# %%
women_shoes = women_shoes[['brand','categories', 'prices.amountMax', 'prices.amountMin','prices.currency', 'colors', 'name','sizes','features','reviews']]
women_shoes
# Out:
#                  brand                                         categories  \
# 0          Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# ...                ...                                                ...
# 33796           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33797           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33798           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33799  City Classified                        Clothing,,Women,Shoes,Pumps
# 33800           Vionic                      Women,Shoes,Sandals,Clothing,
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 0                 55.99             55.99             USD
# 1                 47.00             35.25             USD
# 2                 35.25             35.25             USD
# 3                 24.75             24.75             USD
# 4                 33.00             30.39             USD
# ...                 ...               ...             ...
# 33796             43.19             43.19             USD
# 33797             39.99             39.99             USD
# 33798             35.99             35.99             USD
# 33799             25.64             25.64             USD
# 33800             47.99             47.99             USD
#
#                                colors  \
# 0      Silver,Cream Watercolor Floral
# 1                                Grey
# 2                                Grey
# 3                               Black
# 4                                Grey
# ...                               ...
# 33796                            Blue
# 33797                             Red
# 33798                             Red
# 33799                             NaN
# 33800                             NaN
#
#                                                     name  \
# 0      Naturalizer Danya Women N/S Open Toe Synthetic...
# 1                    MUK LUKS Womens Jane Suede Moccasin
# 2                    MUK LUKS Womens Jane Suede Moccasin
# 3               MUK LUKS Womens Dawn Suede Scuff Slipper
# 4               MUK LUKS Womens Dawn Suede Scuff Slipper
# ...                                                  ...
# 33796  Handcrafted Cotton Blend 'Garden in Blue' Card...
# 33797  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33798  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33799  City Classified Women's Closed Toe Mary Jane C...
# 33800                        Vionic Women's Jura Sandals
#
#                                                    sizes  \
# 0      6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                             10,7,6,9,8
# 2                                             10,7,6,9,8
# 3                                             10,7,6,9,8
# 4                                             10,7,6,9,8
# ...                                                  ...
# 33796                                                NaN
# 33797                                                NaN
# 33798                                                NaN
# 33799                                                NaN
# 33800                                                NaN
#
#                                                 features reviews
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 33796  [{"key":"Worldstock Country","value":["Peru"]}...     NaN
# 33797  [{"key":"Worldstock Country","value":["Peru"]}...     NaN
# 33798  [{"key":"Worldstock Country","value":["Peru"]}...     NaN
# 33799                                                NaN     NaN
# 33800                                                NaN     NaN
#
# [53801 rows x 10 columns]

# %%
import json
import math
import sys


def extract_averge_review(reviews):
    try:
        if (type(reviews) == float):
            return None
        
        if (type(reviews) != str):
            #print( f"WARN not a string but a {type(reviews)} {reviews}" )
            return None
        
        reviews = reviews.replace("\\\\", "\\")
        kvs = json.loads(reviews)
        ratings = []
        for kv in kvs:
            if("rating" in kv):
                #print( f"\n\n{kv}" )
                ratings.append( float( kv["rating"] ) )
                
        #print( f"\n\n{ratings}" )
        
        # questo blocco è per fare qualcosa di utile con i voti di un prodotto.
        # ad esempio in questo caso viene calcolata la media delle recensioni
        if len(ratings) == 0:
            return None
        else:
            total = 0.0
            for r in ratings:
                total = total + r
            avg = total / len(ratings)
            return avg        
                
    except:
        err_type, err_value, err_traceback = sys.exc_info()
        #print( f"WARN '{err_type}' '{err_value}' parsing {reviews}" )
        return None

# %%
reduced_women = pd.DataFrame()
reduced_women['brand'] = women_shoes['brand']
reduced_women['categories'] = women_shoes['categories']
reduced_women['prices.amountMax'] = women_shoes['prices.amountMax']
reduced_women['prices.amountMin'] = women_shoes['prices.amountMin']
reduced_women['prices.currency'] = women_shoes['prices.currency']
reduced_women['colors'] = women_shoes['colors'] 
reduced_women['name'] = women_shoes['name']
reduced_women['sizes'] = women_shoes['sizes'] 
reduced_women['features'] = women_shoes['features']
reduced_women['reviews'] = women_shoes['reviews'].apply(extract_averge_review)
reduced_women
# Out:
#                  brand                                         categories  \
# 0          Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2             MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4             MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# ...                ...                                                ...
# 33796           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33797           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33798           Novica            Access.,Clothing,Shoes,Women's Clothing
# 33799  City Classified                        Clothing,,Women,Shoes,Pumps
# 33800           Vionic                      Women,Shoes,Sandals,Clothing,
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 0                 55.99             55.99             USD
# 1                 47.00             35.25             USD
# 2                 35.25             35.25             USD
# 3                 24.75             24.75             USD
# 4                 33.00             30.39             USD
# ...                 ...               ...             ...
# 33796             43.19             43.19             USD
# 33797             39.99             39.99             USD
# 33798             35.99             35.99             USD
# 33799             25.64             25.64             USD
# 33800             47.99             47.99             USD
#
#                                colors  \
# 0      Silver,Cream Watercolor Floral
# 1                                Grey
# 2                                Grey
# 3                               Black
# 4                                Grey
# ...                               ...
# 33796                            Blue
# 33797                             Red
# 33798                             Red
# 33799                             NaN
# 33800                             NaN
#
#                                                     name  \
# 0      Naturalizer Danya Women N/S Open Toe Synthetic...
# 1                    MUK LUKS Womens Jane Suede Moccasin
# 2                    MUK LUKS Womens Jane Suede Moccasin
# 3               MUK LUKS Womens Dawn Suede Scuff Slipper
# 4               MUK LUKS Womens Dawn Suede Scuff Slipper
# ...                                                  ...
# 33796  Handcrafted Cotton Blend 'Garden in Blue' Card...
# 33797  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33798  Handcrafted Acrylic Alpaca Blend 'Red Dreamcat...
# 33799  City Classified Women's Closed Toe Mary Jane C...
# 33800                        Vionic Women's Jura Sandals
#
#                                                    sizes  \
# 0      6W,9W,7.5W,12W,8.5M,9N,9M,9.5M,10.5M,10W,8.5W,...
# 1                                             10,7,6,9,8
# 2                                             10,7,6,9,8
# 3                                             10,7,6,9,8
# 4                                             10,7,6,9,8
# ...                                                  ...
# 33796                                                NaN
# 33797                                                NaN
# 33798                                                NaN
# 33799                                                NaN
# 33800                                                NaN
#
#                                                 features  reviews
# 0                                                    NaN      NaN
# 1                                                    NaN      NaN
# 2                                                    NaN      NaN
# 3                                                    NaN      NaN
# 4                                                    NaN      NaN
# ...                                                  ...      ...
# 33796  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33797  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33798  [{"key":"Worldstock Country","value":["Peru"]}...      NaN
# 33799                                                NaN      NaN
# 33800                                                NaN      NaN
#
# [53801 rows x 10 columns]

# %%
reduced_women['categories'].unique()

# %%
rows = reduced_women["categories"].unique()
#print(rows)
s = set()
for row in rows:
    #print("-- " + row)
    categories = row.split(",")
    for category in categories:
        ##print("---- " + category)
        s.add(category)

print(s)
# Out:
# {'', 'Uniforms', 'Fila', 'Hair Accessories', 'Baby', "Men's Activewear", 'Winter', 'Kisses by 2 Lips Too', '#23400 in', 'Slides', 'Beacon Shoes', 'Work', 'Sports', 'Mules', "Women's New Balance Shoes", 'Mid-Calf', 'Fragrances', 'Handbag Organizers', 'Running Shoes', 'Premium Womens Boots', 'Nature Breeze', 'AnyWear', 'Boots', '#100 in', 'Toe Warmers', 'Shop by Clothing Type', 'Work Boots', 'See more Pajar 1695 Womens Iceberg Brown Suede Winter B...', 'Premium Womens Comfort', 'Athletic', 'Swimwear', '#350 in', 'Collectible Figurines', 'See more Women Bearpaw Knit Tall Boot 658w Black 100 Au...', "Women's Sandals", 'Fashions for Her', 'New Balance', 'Protective Gear', 'Valentine%27s Day', 'Luggage', 'DimeCity', 'ASICS', 'Wrist Watches', 'Mark and Maddux', 'See more ALDO 6422 Womens Vitaly Black Leather HEELS Kn...', 'By Personality', 'Premium Womens Shoes', 'See more Rampage Imelda Brown Tall Riding BOOTS Womens ...', 'See more Penny Loves Kenny 3560 Womens Dallas Black Qui...', 'Wedge Pumps', 'Hades', 'Loafers & Slip-Ons', ' Work & Safety', 'Ryka', 'Adriana', 'Pin Up', 'See more Dingo 5299 Womens Sonnet Brown Cowboy Western ...', 'Running', 'Home', '#2', 'Womens Sport Sandals', 'Spring Step', 'Fastpitch Softball', "See more Women's Minnetonka Moccasin Thunderbird II Moc...", '298 in', 'household essentials', 'Simply Vera Vera Wang', 'Old Friend', 'Betula by Birkenstock', 'All Action Sports', 'See more Tecnica Moon Boot Nylon White Womens Winter BO...', "Women's Workwear & Uniforms", 'All Womens Flats', 'Active', 'Medical Uniforms', 'NAYA', ' Reenactment', 'Espadrille', 'Pumps', 'See more Michael Kors MK Flex Pump Merlot Womens Suede ...', 'Neutral', 'Outdoor', 'SIDEKICK', '#27273 in', '944 in', 'Golf', 'Home Improvement', 'Golf Equipment', 'See more Michael Kors Fulton MOC Washed Denim Shoes Fla...', 'Sporting Goods', 'Womens Flats D*Orsay', 'Oxford', 'Womens Slip-resistant', 'See more Baretraps Sinclair Womens Size 8 Black Leather...', 'Altra Footwear', 'Troentorp Bastad Clogs', 'All Costumes', 'Bowling', 'Suits & Blazers', 'Shoes & Handbags', '#73234 in', 'Other Slip-Ons', 'Power Tools', '#2616 in', 'Hiking Boots', '748 in', "Women's Running Shoes", "Women's Cleats", 'Rain', 'FIC', 'Hailey Jeans Co.', 'Women%27s Fashion', 'Cross Training', 'Indian Selections', 'Foot Care', "Women's Flats", '#97541 in', 'See more Crush by Durango Womens Brown Heartbreaker Boo...', '#3531 in', 'Diba True', 'Casual Lace', "Women's Watches", 'Womens Shoes', ' Shoes', 'Croft', 'Sale', 'Flip-Flops', 'Barrow', 'Home Décor Accents', 'Tools', 'Apt. 9', 'Skate Shoes', 'Winter Shoes', '#3414 in', 'Electronics', 'Dance & Gymnastics', 'Workwear & Uniforms', 'Blue', 'Watches', '#468 in', 'Lamo', 'MUK LUKS', "Candie's", 'Unionbay', "All Women's Clothing", 'Juniors Skirts', 'FILA', 'All Work Shoes', 'Adidas', 'Vaneli', 'Sneakers & Athletic Shoes', 'Refresh', 'Peep Toe', 'USA Dawgs', 'Slip-ons', 'In-sattva', 'Halloween Accessories', 'See more Steve Madden Evrlast Women US 6 Gold Flats Ble...', '#805 in', 'See more LifeStride 9770 Womens Sasha Black Riding BOOT...', 'Wild Diva', 'RocSoc', 'Shoes', 'Walking Shoes', 'Acorn', 'Gravity Defyer', 'Heeled Sandals', 'For Her', 'Novica', 'Dolce by Mojo Moxy', '#10000 in', '#244 in', 'Pointed Toe', '#6', 'Costumes', '#5', 'LC Lauren Conrad', 'Baseball Cleats', 'Under Armour', 'Occupational', "Women's Protective Eyewear", 'See more Kenneth Cole Reactio Slim Shake Women US 7 Bla...', '#341 in', 'Rieker-Antistress', 'Safety', 'Mary Jane Flats', 'Boat Shoes', 'Platform', 'Sam Edelman', "Women's Wear to Work", 'See more Vince Camuto 3520 Womens Lorim Black Platform ...', 'Cliffs By White Mountain', 'Action Sports Outlet', 'Handbag Accessories', 'See more Harley-Davidson Summer Womens Black Leather Sl...', 'A2 by Aerosoles', 'Apparel', "Girls' Shoes", 'Fine', 'Golf Shoes', 'SONOMA Goods for Life', 'Apex', 'Hand Tools', 'Special Offers', 'See more Khombu 0650 Womens JAS Black Leather Winter BO...', 'Henry Ferrera', 'Cleats',  ...

# %%
to_save = ['Sneakers', 'Fashion Sneakers','Nike', 'Team Sports', 'Sports', 'Adidas', 'Basketball','Gravity Defyer',"Womens' Athletic Shoes",'Trendsetter','Athletic', 'Slip-ons','Skateboarding', 'Basketball Shoes','Running','Walking Shoes', 'Running Shoes',"Women's Athletic Shoes", "See more ASICS Women's Gel-nimbus 16 Running Shoe Light...", 'Skechers']
def cat_def(x):
    p = ''
    for cat_to_save in to_save:
        if cat_to_save in x :
            return cat_to_save

   

            
#reduced_women['my_categories']=reduced_women['categories'].apply(cat_def)
#reduced_women
            


#reduced_women['categories'].apply(cat_def)

# %%
reduced_women['my_categories']=reduced_women['categories'].apply(cat_def)

# %%
reduced_women = reduced_women[reduced_women['my_categories'].isnull()==False]
reduced_women
# Out:
#           brand                                         categories  \
# 27     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 28     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 29     SKECHERS  Sneakers,Womens Shoes,Clothing,Work Safety Clo...
# 30     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# 31     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# ...         ...                                                ...
# 33757  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33758  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33759  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33760  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33761  Skechers                       Shoes,Slip-ons,Women's Shoes
#
#        prices.amountMax  prices.amountMin prices.currency       colors  \
# 27                85.00             85.00             USD        Black
# 28                85.00             85.00             USD        Black
# 29                75.00             75.00             USD        Black
# 30                49.99             44.99             USD  Taupe,White
# 31                49.99             49.99             USD  Taupe,White
# ...                 ...               ...             ...          ...
# 33757             44.36             44.36             USD          NaN
# 33758             44.36             44.36             USD          NaN
# 33759             44.36             44.36             USD          NaN
# 33760             44.36             44.36             USD          NaN
# 33761             44.36             44.36             USD          NaN
#
#                                                     name  \
# 27     Skechers Women's Skech-Air Lingle Black Memory...
# 28     Skechers Women's Skech-Air Lingle Black Memory...
# 29     76580 W Wide Width Black Skechers Shoe New Wom...
# 30     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# 31     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# ...                                                  ...
# 33757  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33758  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33759  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33760  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33761  Women's Skechers Relaxed Fit Breathe Easy Fait...
#
#                                 sizes features  reviews my_categories
# 27      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN      Sneakers
# 28      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN      Sneakers
# 29     5,5.5,6,6.5,7.5,9.5,9.5 WIDE,7      NaN      NaN      Sneakers
# 30                    5,6,7,8,9,10,11      NaN      NaN      Skechers
# 31                    5,6,7,8,9,10,11      NaN      NaN      Skechers
# ...                               ...      ...      ...           ...
# 33757                             NaN      NaN      NaN      Slip-ons
# 33758                             NaN      NaN      NaN      Slip-ons
# 33759                             NaN      NaN      NaN      Slip-ons
# 33760                             NaN      NaN      NaN      Slip-ons
# 33761                             NaN      NaN      NaN      Slip-ons
#
# [7786 rows x 11 columns]

# %%
import json
import math
import sys

# %%
def extract_material(features_json):
    # [{"key":"Material","value":["Suede"]},{"key":"Gender","value":["Men"]},{"key":"Color","value":["Beige"]},{"key":"Model","value":["M254TNN"]},{"key":"Manufacturer Part Number","value":["M254TNN"]},{"key":"Brand","value":["New Balance Numeric"]},{"key":"Age Group","value":["Adult"]}]    
    try:
        if (type(features_json) == float):
            return None
        
        if (type(features_json) != str):
            print( f"WARN not a string but a {type(features_json)} {features_json}" )
            return None
        
        features_json = features_json.replace("\\\\", "\\")
        kvs = json.loads(features_json)
        for kv in kvs:
            if(kv["key"] == "Material"):
                return kv["value"][0]
            
        return None
    except:
        err_type, err_value, err_traceback = sys.exc_info()
        print( f"WARN '{err_type}' '{err_value}' parsing {features_json}" )
        return None

# %%
reduced_women['material']=reduced_women['features'].apply(extract_material)
reduced_women
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           brand                                         categories  \
# 27     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 28     SKECHERS  Womens,Sneakers,Womens Casual Shoes,Womens Sho...
# 29     SKECHERS  Sneakers,Womens Shoes,Clothing,Work Safety Clo...
# 30     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# 31     SKECHERS  Womens,Womens Shoes,Clothing,Women's Shoes,All...
# ...         ...                                                ...
# 33757  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33758  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33759  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33760  Skechers                       Shoes,Slip-ons,Women's Shoes
# 33761  Skechers                       Shoes,Slip-ons,Women's Shoes
#
#        prices.amountMax  prices.amountMin prices.currency       colors  \
# 27                85.00             85.00             USD        Black
# 28                85.00             85.00             USD        Black
# 29                75.00             75.00             USD        Black
# 30                49.99             44.99             USD  Taupe,White
# 31                49.99             49.99             USD  Taupe,White
# ...                 ...               ...             ...          ...
# 33757             44.36             44.36             USD          NaN
# 33758             44.36             44.36             USD          NaN
# 33759             44.36             44.36             USD          NaN
# 33760             44.36             44.36             USD          NaN
# 33761             44.36             44.36             USD          NaN
#
#                                                     name  \
# 27     Skechers Women's Skech-Air Lingle Black Memory...
# 28     Skechers Women's Skech-Air Lingle Black Memory...
# 29     76580 W Wide Width Black Skechers Shoe New Wom...
# 30     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# 31     Skechers 38562BLK Women's RUMBLERS - HOTSHOT S...
# ...                                                  ...
# 33757  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33758  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33759  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33760  Women's Skechers Relaxed Fit Breathe Easy Fait...
# 33761  Women's Skechers Relaxed Fit Breathe Easy Fait...
#
#                                 sizes features  reviews my_categories material
# 27      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN      Sneakers     None
# 28      6,6.5,7,7.5,8,8.5,9,9.5,10,11      NaN      NaN      Sneakers     None
# 29     5,5.5,6,6.5,7.5,9.5,9.5 WIDE,7      NaN      NaN      Sneakers     None
# 30                    5,6,7,8,9,10,11      NaN      NaN      Skechers     None
# 31                    5,6,7,8,9,10,11      NaN      NaN      Skechers     None
# ...                               ...      ...      ...           ...      ...
# 33757                             NaN      NaN      NaN      Slip-ons     None
# 33758                             NaN      NaN      NaN      Slip-ons     None
# 33759                             NaN      NaN      NaN      Slip-ons     None
# 33760                             NaN      NaN      NaN      Slip-ons     None
# 33761                             NaN      NaN      NaN      Slip-ons     None
#
# [7786 rows x 12 columns]

# %%
reduced_women['my_categories'].value_counts()

# %%
reduced_women['brand'].value_counts().head(n=20)

# %%
from collections import Counter

# %%
freq_material = reduced_women['brand']
count_freq_brand = Counter(freq_material)
df = pd.DataFrame.from_dict(count_freq_brand, orient='index')
df.plot(kind='bar')

# %%
reduced_women=reduced_women[reduced_women["material"].isnull()==False]
reduced_women
# Out:
#              brand                                         categories  \
# 161          ASICS                             Athletic,Women's Shoes
# 162          ASICS                             Athletic,Women's Shoes
# 323    New Balance                             Women's Shoes,Athletic
# 392           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# 393           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# ...            ...                                                ...
# 24589       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24590       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24591       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24691     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
# 24692     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 161              159.99            159.99             USD
# 162               99.99             99.99             USD
# 323               44.99             44.99             USD
# 392               39.66             39.66             USD
# 393               35.99             35.99             USD
# ...                 ...               ...             ...
# 24589             56.90             56.90             USD
# 24590             56.90             56.90             USD
# 24591             56.43             56.43             USD
# 24691             69.90             69.90             USD
# 24692             65.00             65.00             USD
#
#                          colors  \
# 161    IRIDESCENTPINKCAPRI BLUE
# 162    IRIDESCENTPINKCAPRI BLUE
# 323                       White
# 392                 Multi-Color
# 393                 Multi-Color
# ...                         ...
# 24589                     Brown
# 24590                     Brown
# 24591                     Brown
# 24691          Black,BlackBlack
# 24692          Black,BlackBlack
#
#                                                     name sizes  \
# 161    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 162    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 323      New Balance Ww496 Women Us 9 White Walking Shoe     9
# 392    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# 393    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# ...                                                  ...   ...
# 24589  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24590  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24591  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24691  Converse Women's Chuck Taylor All Star Madison...   NaN
# 24692  Converse Women's Chuck Taylor All Star Madison...   NaN
#
#                                                 features  reviews  \
# 161    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 162    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 323    [{"key":"Style","value":["Walking"]},{"key":"E...      NaN
# 392    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# 393    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# ...                                                  ...      ...
# 24589  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24590  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24591  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24691  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24692  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
#
#                 my_categories   material
# 161                  Athletic       MESH
# 162                  Athletic       MESH
# 323                  Athletic  Synthetic
# 392                  Athletic    Textile
# 393                  Athletic    Textile
# ...                       ...        ...
# 24589                Athletic    Leather
# 24590                Athletic    Leather
# 24591                Athletic    Leather
# 24691  Womens' Athletic Shoes    Leather
# 24692  Womens' Athletic Shoes    Leather
#
# [678 rows x 12 columns]

# %%
rows = reduced_women['material'].unique()
#print(rows)
s = set()
for row in rows:
    #print("-- " + row)
    categories = row.split(",")
    for category in categories:
        ##print("---- " + category)
        s.add(category)

print(s)
# Out:
# {'Canvas/Suede', 'canvas', 'Synthetic Upper/Rubber Sole', '.', 'Fabric/Man Made', 'Unknown', 'leather', 'Leather-And-Synthetic', 'Man Made', 'leather-and-fabric', 'rubber', 'Synthetic-And-Mesh', 'Synthetic Leather', 'Leather', 'MESH', 'Synthetic/Mesh', 'polyester', 'Synthetic-And-Leather', 'No Material Tag', 'Canvas', 'Textile', 'Leather/Lorica', 'Cork', 'Synthetic/Nylon', 'Flyknit', 'Mesh', 'Faux Suede', 'Leather/Man Made', 'Suede', 'Patent-Leather', 'Synthetic', 'Man Made/Fabric', 'Synthetic/Nylon/Rubber', 'Wool', 'Lightweight Fabric/Foam', 'Glitter'}

# %%
mat_to_save = ['rubber','canvas','Suede','Synthetic','Textile','Leather','Flyknit','Wool','Mesh','polyester','Cork','Man Made','leather','MESH','Synthetic-And-Mesh','Synthetic/Nylon/Rubber','Patent-Leather','Synthetic/Mesh','Synthetic Upper/Rubber Sole','Faux Suede','Synthetic Leather','Canvas/Suede']

# %%
def mat_def(x):
    for mat in mat_to_save:
        if mat in x :
            return (mat)
    return 'altro'

   

            
reduced_women['my_material']=reduced_women['material'].apply(mat_def)
reduced_women
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#              brand                                         categories  \
# 161          ASICS                             Athletic,Women's Shoes
# 162          ASICS                             Athletic,Women's Shoes
# 323    New Balance                             Women's Shoes,Athletic
# 392           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# 393           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# ...            ...                                                ...
# 24589       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24590       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24591       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24691     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
# 24692     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 161              159.99            159.99             USD
# 162               99.99             99.99             USD
# 323               44.99             44.99             USD
# 392               39.66             39.66             USD
# 393               35.99             35.99             USD
# ...                 ...               ...             ...
# 24589             56.90             56.90             USD
# 24590             56.90             56.90             USD
# 24591             56.43             56.43             USD
# 24691             69.90             69.90             USD
# 24692             65.00             65.00             USD
#
#                          colors  \
# 161    IRIDESCENTPINKCAPRI BLUE
# 162    IRIDESCENTPINKCAPRI BLUE
# 323                       White
# 392                 Multi-Color
# 393                 Multi-Color
# ...                         ...
# 24589                     Brown
# 24590                     Brown
# 24591                     Brown
# 24691          Black,BlackBlack
# 24692          Black,BlackBlack
#
#                                                     name sizes  \
# 161    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 162    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 323      New Balance Ww496 Women Us 9 White Walking Shoe     9
# 392    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# 393    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# ...                                                  ...   ...
# 24589  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24590  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24591  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24691  Converse Women's Chuck Taylor All Star Madison...   NaN
# 24692  Converse Women's Chuck Taylor All Star Madison...   NaN
#
#                                                 features  reviews  \
# 161    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 162    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 323    [{"key":"Style","value":["Walking"]},{"key":"E...      NaN
# 392    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# 393    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# ...                                                  ...      ...
# 24589  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24590  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24591  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24691  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24692  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
#
#                 my_categories   material my_material
# 161                  Athletic       MESH        MESH
# 162                  Athletic       MESH        MESH
# 323                  Athletic  Synthetic   Synthetic
# 392                  Athletic    Textile     Textile
# 393                  Athletic    Textile     Textile
# ...                       ...        ...         ...
# 24589                Athletic    Leather     Leather
# 24590                Athletic    Leather     Leather
# 24591                Athletic    Leather     Leather
# 24691  Womens' Athletic Shoes    Leather     Leather
# 24692  Womens' Athletic Shoes    Leather     Leather
#
# [678 rows x 13 columns]

# %%
reduced_women['my_material'].value_counts()
# Out:
# Synthetic    207
# Mesh         202
# Leather      101
# altro         59
# Textile       57
# Suede         35
# Flyknit        7
# Sinthetic      7
# rubber         3
# Name: my_material, dtype: int64

# %%
reduced_women['my_material'] = reduced_women['my_material'].str.replace('MESH', 'Mesh')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('leather', 'Leather')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('polyester','Synthetic')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('Man Made', 'Synthetic')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('Sinthetic','Synthetic')
reduced_women['my_material']  = reduced_women['my_material'].str.replace('canvas', 'Textile')
reduced_women['my_material']  = reduced_women['my_material'].str.replace( 'Cork', 'Textile')
reduced_women['my_material']  = reduced_women['my_material'].str.replace( 'Wool','Textile')
reduced_women
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              brand                                         categories  \
# 161          ASICS                             Athletic,Women's Shoes
# 162          ASICS                             Athletic,Women's Shoes
# 323    New Balance                             Women's Shoes,Athletic
# 392           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# 393           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# ...            ...                                                ...
# 24589       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24590       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24591       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24691     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
# 24692     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 161              159.99            159.99             USD
# 162               99.99             99.99             USD
# 323               44.99             44.99             USD
# 392               39.66             39.66             USD
# 393               35.99             35.99             USD
# ...                 ...               ...             ...
# 24589             56.90             56.90             USD
# 24590             56.90             56.90             USD
# 24591             56.43             56.43             USD
# 24691             69.90             69.90             USD
# 24692             65.00             65.00             USD
#
#                          colors  \
# 161    IRIDESCENTPINKCAPRI BLUE
# 162    IRIDESCENTPINKCAPRI BLUE
# 323                       White
# 392                 Multi-Color
# 393                 Multi-Color
# ...                         ...
# 24589                     Brown
# 24590                     Brown
# 24591                     Brown
# 24691          Black,BlackBlack
# 24692          Black,BlackBlack
#
#                                                     name sizes  \
# 161    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 162    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 323      New Balance Ww496 Women Us 9 White Walking Shoe     9
# 392    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# 393    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# ...                                                  ...   ...
# 24589  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24590  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24591  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24691  Converse Women's Chuck Taylor All Star Madison...   NaN
# 24692  Converse Women's Chuck Taylor All Star Madison...   NaN
#
#                                                 features  reviews  \
# 161    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 162    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 323    [{"key":"Style","value":["Walking"]},{"key":"E...      NaN
# 392    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# 393    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# ...                                                  ...      ...
# 24589  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24590  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24591  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24691  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24692  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
#
#                 my_categories   material my_material
# 161                  Athletic       MESH        Mesh
# 162                  Athletic       MESH        Mesh
# 323                  Athletic  Synthetic   Synthetic
# 392                  Athletic    Textile     Textile
# 393                  Athletic    Textile     Textile
# ...                       ...        ...         ...
# 24589                Athletic    Leather     Leather
# 24590                Athletic    Leather     Leather
# 24591                Athletic    Leather     Leather
# 24691  Womens' Athletic Shoes    Leather     Leather
# 24692  Womens' Athletic Shoes    Leather     Leather
#
# [678 rows x 13 columns]

# %%
reduced_women['my_material'].value_counts()
# Out:
# Synthetic    214
# Mesh         202
# Leather      101
# altro         59
# Textile       57
# Suede         35
# Flyknit        7
# rubber         3
# Name: my_material, dtype: int64

# %%
reduced_women['my_material'].value_counts(normalize=True)
# Out:
# Synthetic    0.315634
# Mesh         0.297935
# Leather      0.148968
# altro        0.087021
# Textile      0.084071
# Suede        0.051622
# Flyknit      0.010324
# rubber       0.004425
# Name: my_material, dtype: float64

# %%
from collections import Counter

# %%
freq_material = reduced_women['my_material']
count_freq_material = Counter(freq_material)
df = pd.DataFrame.from_dict(count_freq_material, orient='index')
df.plot(kind='bar')

# %%
reduced_women=reduced_women[reduced_women["colors"].isnull()==False]
reduced_women
# Out:
#              brand                                         categories  \
# 161          ASICS                             Athletic,Women's Shoes
# 162          ASICS                             Athletic,Women's Shoes
# 323    New Balance                             Women's Shoes,Athletic
# 392           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# 393           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# ...            ...                                                ...
# 24589       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24590       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24591       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24691     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
# 24692     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 161              159.99            159.99             USD
# 162               99.99             99.99             USD
# 323               44.99             44.99             USD
# 392               39.66             39.66             USD
# 393               35.99             35.99             USD
# ...                 ...               ...             ...
# 24589             56.90             56.90             USD
# 24590             56.90             56.90             USD
# 24591             56.43             56.43             USD
# 24691             69.90             69.90             USD
# 24692             65.00             65.00             USD
#
#                          colors  \
# 161    IRIDESCENTPINKCAPRI BLUE
# 162    IRIDESCENTPINKCAPRI BLUE
# 323                       White
# 392                 Multi-Color
# 393                 Multi-Color
# ...                         ...
# 24589                     Brown
# 24590                     Brown
# 24591                     Brown
# 24691          Black,BlackBlack
# 24692          Black,BlackBlack
#
#                                                     name sizes  \
# 161    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 162    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 323      New Balance Ww496 Women Us 9 White Walking Shoe     9
# 392    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# 393    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# ...                                                  ...   ...
# 24589  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24590  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24591  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24691  Converse Women's Chuck Taylor All Star Madison...   NaN
# 24692  Converse Women's Chuck Taylor All Star Madison...   NaN
#
#                                                 features  reviews  \
# 161    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 162    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 323    [{"key":"Style","value":["Walking"]},{"key":"E...      NaN
# 392    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# 393    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# ...                                                  ...      ...
# 24589  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24590  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24591  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24691  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24692  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
#
#                 my_categories   material my_material
# 161                  Athletic       MESH        Mesh
# 162                  Athletic       MESH        Mesh
# 323                  Athletic  Synthetic   Synthetic
# 392                  Athletic    Textile     Textile
# 393                  Athletic    Textile     Textile
# ...                       ...        ...         ...
# 24589                Athletic    Leather     Leather
# 24590                Athletic    Leather     Leather
# 24591                Athletic    Leather     Leather
# 24691  Womens' Athletic Shoes    Leather     Leather
# 24692  Womens' Athletic Shoes    Leather     Leather
#
# [538 rows x 13 columns]

# %% [markdown]
# rows = reduced_women['colors'].unique()
# #print(rows)
# s = set()
# for row in rows:
#     #print("-- " + row)
#     categories = row.split(",")
#     for category in categories:
#         ##print("---- " + category)
#         s.add(category)
#
# print(s)

# %%
col_to_save = ['Pink', 'Dazzling BlueBlack', 'BlueSIlver', 'Ember GlowArctic Orange', 'WhiteBlue', 'Atomic MangoMetallic Silver', 'Yellow', 'Hot Pink', 'Pink BlastBlkElctrc GrnWhite', 'Red', 'Pure PlatinumBlackHot Lava', 'ParchmentBlackWhite', 'CoralGrey', 'Vizi OrangeCitron', 'WhiteBluePink', 'Tea', 'Purple', 'Bleached LilacBleached Lilac', 'Slime', 'OcgWhtMpt', 'Natural', 'Bright CrimsonDeep GarnetWht', 'WhiteHot PinkEmerald', 'BlackPink Zing', 'White Leather', 'WineBlack', 'Silver', 'RoyalWhite', 'Hypr Orng', 'Off-White', 'CitronBlueCoral', 'PinkWhite', 'Gray', 'Multi-Colored', 'Indigo Tropical BlkTrWt', 'NtrlBlcdblc', 'Orange', 'Deep BlueWhiteHot Pink', 'Beach GlassDiva PinkMint', 'Dark GrayTealLight Green', 'WhiteBlackWhite', 'BlueTeaPink', 'BeigeRoyal Purple', 'BlackBright Cherry SuedeTextile', 'Sandstone', 'WhiteBlueR', 'Oxblood', 'Vvd Purple', 'VebWhtMed', 'White Synthetic', 'Black', 'Dark GreyWhiteBlack', 'SparkleLinen', 'Citron', 'Linen', 'Blk', 'Green', 'BlackWhiteAnthracite', 'Brown', 'Oranges', 'Sassy Brown', 'HerWhtLml', 'White', 'University RedBrght CrmsnBlk', 'SilverTurquoiseLime Punch', 'True White', 'Vvd PurpleWhiteBlkHypr Orng', 'BlackWhite', 'BlackBlack', 'WhiteVirtual Pink', 'TurquoiseSharp GreenInk', 'OatmealOatmealOatmealBlack', 'Fuchsia', 'Coral', 'Anthracite', 'OnyxPurpleMint', 'TpinkWhiteGlg', 'Gold', 'Nbl BlueNvyWht', 'BlkWhite', 'Grey', 'Vizi Orange', 'BlackBlack Cool Grey', 'GreySlimePink', 'Blue', 'IRIDESCENTPINKCAPRI BLUE', 'BlackPinkGraySilver', 'White Blue', 'EmeraldSilverEmerald', 'WhitePink', 'Pure PlatinumBlckWlf GryWht', 'BlackWhiteCool GreyAnthracite', 'Vivid Sulfur', 'SilverPink', 'Multicolor', 'Beige', 'Mesh', 'Lt Yllw', 'DrkShdw', 'Multi-Color', 'BlackWhiteDark GreyAnthrct', 'LightningWhiteTurquoise', 'Tan', 'BlackBlackWhite', 'Sand', 'WhiteFuschia', 'Coffee']

# %% [markdown]
# Dato che Fiora voleva una panoramica dei colori disponibili ho fatto la nostra solita funzione mettendo tutti i colori a disposizione splittati. Poi li riassegneremo per ml

# %%
def col_def(x):
    for col in col_to_save:
        if col in x :
            return (col)
    return 'altro'

reduced_women['my_colors']=reduced_women['colors'].apply(col_def)
reduced_women
# Out:
# C:\Users\bossi\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#              brand                                         categories  \
# 161          ASICS                             Athletic,Women's Shoes
# 162          ASICS                             Athletic,Women's Shoes
# 323    New Balance                             Women's Shoes,Athletic
# 392           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# 393           Vans  Women's Shoes,Athletic,See more VANS Authentic...
# ...            ...                                                ...
# 24589       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24590       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24591       Sperry  Boots,Shoes,Women's Shoes,Clothing,Women's Ath...
# 24691     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
# 24692     Converse  Shoes,Women's Shoes,Womens' Athletic Shoes,Ath...
#
#        prices.amountMax  prices.amountMin prices.currency  \
# 161              159.99            159.99             USD
# 162               99.99             99.99             USD
# 323               44.99             44.99             USD
# 392               39.66             39.66             USD
# 393               35.99             35.99             USD
# ...                 ...               ...             ...
# 24589             56.90             56.90             USD
# 24590             56.90             56.90             USD
# 24591             56.43             56.43             USD
# 24691             69.90             69.90             USD
# 24692             65.00             65.00             USD
#
#                          colors  \
# 161    IRIDESCENTPINKCAPRI BLUE
# 162    IRIDESCENTPINKCAPRI BLUE
# 323                       White
# 392                 Multi-Color
# 393                 Multi-Color
# ...                         ...
# 24589                     Brown
# 24590                     Brown
# 24591                     Brown
# 24691          Black,BlackBlack
# 24692          Black,BlackBlack
#
#                                                     name sizes  \
# 161    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 162    Asics Gel-nimbus 16 Women's Us Sz 7 Iridescent...     7
# 323      New Balance Ww496 Women Us 9 White Walking Shoe     9
# 392    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# 393    A1650 - Vans Authentic Lo Pro Shoes * New Wome...     8
# ...                                                  ...   ...
# 24589  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24590  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24591  Sperry Top-Sider Women's Heron Seal Brown Leat...   NaN
# 24691  Converse Women's Chuck Taylor All Star Madison...   NaN
# 24692  Converse Women's Chuck Taylor All Star Madison...   NaN
#
#                                                 features  reviews  \
# 161    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 162    [{"key":"Style","value":["GEL-NIMBUS 16"]},{"k...      NaN
# 323    [{"key":"Style","value":["Walking"]},{"key":"E...      NaN
# 392    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# 393    [{"key":"Style","value":["Skate / Casual"]},{"...      NaN
# ...                                                  ...      ...
# 24589  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24590  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24591  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24691  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
# 24692  [{"key":"Shoe Width","value":["Medium","B(M)"]...      NaN
#
#                 my_categories   material my_material                 my_colors
# 161                  Athletic       MESH        Mesh  IRIDESCENTPINKCAPRI BLUE
# 162                  Athletic       MESH        Mesh  IRIDESCENTPINKCAPRI BLUE
# 323                  Athletic  Synthetic   Synthetic                     White
# 392                  Athletic    Textile     Textile               Multi-Color
# 393                  Athletic    Textile     Textile               Multi-Color
# ...                       ...        ...         ...                       ...
# 24589                Athletic    Leather     Leather                     Brown
# 24590                Athletic    Leather     Leather                     Brown
# 24591                Athletic    Leather     Leather                     Brown
# 24691  Womens' Athletic Shoes    Leather     Leather                     Black
# 24692  Womens' Athletic Shoes    Leather     Leather                     Black
#
# [538 rows x 14 columns]

# %%
reduced_women['my_colors'].value_counts(normalize=True)
# Out:
# Black                              0.165428
# Pink                               0.141264
# Red                                0.089219
# White                              0.076208
# Silver                             0.063197
# Blue                               0.035316
# Grey                               0.033457
# Brown                              0.027881
# Orange                             0.026022
# White Synthetic                    0.024164
# Gray                               0.024164
# Purple                             0.022305
# Multi-Color                        0.022305
# VebWhtMed                          0.022305
# Off-White                          0.020446
# WhiteBlue                          0.018587
# CoralGrey                          0.018587
# BlackBright Cherry SuedeTextile    0.016729
# ParchmentBlackWhite                0.013011
# NtrlBlcdblc                        0.013011
# OcgWhtMpt                          0.011152
# Yellow                             0.011152
# Green                              0.009294
# WhiteBlackWhite                    0.009294
# Pure PlatinumBlackHot Lava         0.007435
# White Leather                      0.007435
# Dazzling BlueBlack                 0.005576
# HerWhtLml                          0.005576
# Blk                                0.005576
# Pure PlatinumBlckWlf GryWht        0.005576
# Nbl BlueNvyWht                     0.003717
# Gold                               0.003717
# SparkleLinen                       0.003717
# Atomic MangoMetallic Silver        0.003717
# Beige                              0.003717
# Ember GlowArctic Orange            0.003717
# Linen                              0.003717
# IRIDESCENTPINKCAPRI BLUE           0.003717
# Fuchsia                            0.001859
# Sandstone                          0.001859
# Multicolor                         0.001859
# Oxblood                            0.001859
# Natural                            0.001859
# BlueSIlver                         0.001859
# Vivid Sulfur                       0.001859
# RoyalWhite                         0.001859
# Tea                                0.001859
# Indigo Tropical BlkTrWt            0.001859
# Name: my_colors, dtype: float64
