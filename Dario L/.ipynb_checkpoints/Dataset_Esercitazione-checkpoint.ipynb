# %%
import pandas as pd

# %%
#link: https://www.kaggle.com/saadalsharif/smartphone
mobile = pd.read_csv("../../mobile.csv")
mobile
# Out:
#       Unnamed: 0                                               name  \
# 0              0  Mione K1 ROM 3GB RAM 32GB 5.99 Inch display 4G...
# 1              1  Porsche design Huawei Mate 20 RS Dual SIM - 512GB
# 2              2               Samsung Galaxy Fold Dual SIM - 512GB
# 3              3               Samsung Galaxy Fold Dual SIM - 512GB
# 4              4             Blackberry P'9981 Porsche Design - 8GB
# ...          ...                                                ...
# 2755        2755        Huawei P40 Pro Single SIM and E-SIM - 256GB
# 2756        2756           Apple iPhone XR without Face Time - 64GB
# 2757        2757             Samsung Galaxy S10 Plus Dual Sim - 1Tb
# 2758        2758              Apple iPhone 11 with FaceTime - 256GB
# 2759        2759           Samsung Galaxy S20 Plus Dual SIM - 128GB
#
#                Generation          Color       Number_Of_SIM      item_price  \
# ...

# %%
mobile ["name"]
# Out:
# 0       Mione K1 ROM 3GB RAM 32GB 5.99 Inch display 4G...
# 1       Porsche design Huawei Mate 20 RS Dual SIM - 512GB
# 2                    Samsung Galaxy Fold Dual SIM - 512GB
# 3                    Samsung Galaxy Fold Dual SIM - 512GB
# 4                  Blackberry P'9981 Porsche Design - 8GB
#                               ...
# 2755          Huawei P40 Pro Single SIM and E-SIM - 256GB
# 2756             Apple iPhone XR without Face Time - 64GB
# 2757               Samsung Galaxy S10 Plus Dual Sim - 1Tb
# 2758                Apple iPhone 11 with FaceTime - 256GB
# 2759             Samsung Galaxy S20 Plus Dual SIM - 128GB
# Name: name, Length: 2760, dtype: object

# %%
#solo modelli samsung
samsung = mobile [mobile["item_brand_name"]=="samsung"]
samsung
# Out:
#       Unnamed: 0                                       name  \
# 2              2       Samsung Galaxy Fold Dual SIM - 512GB
# 3              3       Samsung Galaxy Fold Dual SIM - 512GB
# 25            25     Samsung Galaxy Z Flip Dual SIM - 256GB
# 26            26     Samsung Galaxy Z Flip Dual SIM - 256GB
# 30            30  Samsung Galaxy S20 Ultra Dual SIM - 128GB
# ...          ...                                        ...
# 2746        2746   Samsung Galaxy S20 Plus Dual SIM - 128GB
# 2747        2747   Samsung Galaxy S20 Plus Dual SIM - 128GB
# 2748        2748   Samsung Galaxy S20 Plus Dual SIM - 128GB
# 2757        2757     Samsung Galaxy S10 Plus Dual Sim - 1Tb
# 2759        2759   Samsung Galaxy S20 Plus Dual SIM - 128GB
#
#                Generation          Color   Number_Of_SIM    item_price  \
# 2                  4G LTE         Silver             NaN  7,587.00 SAR
# 3                  4G LTE          Black             NaN  7,099.00 SAR
# ...

# %%
#solo modelli apple
apple = mobile [mobile["item_brand_name"]=="apple"]
apple
# Out:
#       Unnamed: 0                                           name  Generation  \
# 5              5  Apple iPhone 11 Pro Max with FaceTime - 512GB      4G LTE
# 6              6  Apple iPhone 11 Pro Max with FaceTime - 512GB      4G LTE
# 7              7     Apple Iphone XS Max With Facetime - 512 GB      Silver
# 8              8     Apple Iphone XS Max With Facetime - 512 GB  Space Grey
# 11            11      Apple iPhone 11 Pro with FaceTime - 512GB      4G LTE
# ...          ...                                            ...         ...
# 2750        2750          Apple iPhone 11 with FaceTime - 256GB      4G LTE
# 2752        2752      Apple iPhone 7 Plus with FaceTime - 128GB   Jet Black
# 2754        2754    Apple iPhone 8 Plus without FaceTime - 64GB        Gold
# 2756        2756       Apple iPhone XR without Face Time - 64GB      White
# 2758        2758          Apple iPhone 11 with FaceTime - 256GB      4G LTE
#
# ...

# %%
#solo modelli huawei
huawei = mobile [mobile["item_brand_name"]=="huawei"]
huawei
# Out:
#       Unnamed: 0                                               name  \
# 1              1  Porsche design Huawei Mate 20 RS Dual SIM - 512GB
# 10            10      Huawei Mate 9 Porsche Design Dual Sim - 256GB
# 24            24     Huawei Mate RS Porsche Design Dual SIM - 256GB
# 51            51               Huawei Mate 20 Pro Dual Sim - 128 GB
# 53            53        Huawei P40 Pro Single SIM and E-SIM - 256GB
# ...          ...                                                ...
# 2710        2710      Huawei Mate 9 Porsche Design Dual Sim - 256GB
# 2724        2724     Huawei Mate RS Porsche Design Dual SIM - 256GB
# 2751        2751               Huawei Mate 20 Pro Dual Sim - 128 GB
# 2753        2753        Huawei P40 Pro Single SIM and E-SIM - 256GB
# 2755        2755        Huawei P40 Pro Single SIM and E-SIM - 256GB
#
#              Generation     Color Number_Of_SIM    item_price item_brand_name
# ...

# %%
#solo Lte 4g
LTE_4 = mobile [mobile["Generation"]== "4G LTE"]
LTE_4
# Out:
#       Unnamed: 0                                               name  \
# 1              1  Porsche design Huawei Mate 20 RS Dual SIM - 512GB
# 2              2               Samsung Galaxy Fold Dual SIM - 512GB
# 3              3               Samsung Galaxy Fold Dual SIM - 512GB
# 5              5      Apple iPhone 11 Pro Max with FaceTime - 512GB
# 6              6      Apple iPhone 11 Pro Max with FaceTime - 512GB
# ...          ...                                                ...
# 2744        2744              Apple iPhone 11 with FaceTime - 256GB
# 2745        2745              Apple iPhone 11 with FaceTime - 256GB
# 2750        2750              Apple iPhone 11 with FaceTime - 256GB
# 2757        2757             Samsung Galaxy S10 Plus Dual Sim - 1Tb
# 2758        2758              Apple iPhone 11 with FaceTime - 256GB
#
#      Generation          Color       Number_Of_SIM    item_price  \
# 1        4G LTE            Red                 NaN  8,500.00 SAR
# ...

# %%
#tutto ma non Lte 4g
nonLTE_4 = mobile [mobile["Generation"]!= "4G LTE"]
nonLTE_4
# Out:
#       Unnamed: 0                                               name  \
# 0              0  Mione K1 ROM 3GB RAM 32GB 5.99 Inch display 4G...
# 4              4             Blackberry P'9981 Porsche Design - 8GB
# 7              7         Apple Iphone XS Max With Facetime - 512 GB
# 8              8         Apple Iphone XS Max With Facetime - 512 GB
# 9              9                 Google Glass Explorer Edition XE-C
# ...          ...                                                ...
# 2753        2753        Huawei P40 Pro Single SIM and E-SIM - 256GB
# 2754        2754        Apple iPhone 8 Plus without FaceTime - 64GB
# 2755        2755        Huawei P40 Pro Single SIM and E-SIM - 256GB
# 2756        2756           Apple iPhone XR without Face Time - 64GB
# 2759        2759           Samsung Galaxy S20 Plus Dual SIM - 128GB
#
#                Generation     Color       Number_Of_SIM      item_price  \
# 0                     NaN       NaN                 NaN  227,599.00 SAR
# ...

# %%
# modelli apple
modelli_apple = apple ["name"].unique()
modelli_apple.sort()
print(modelli_apple)
count = sum (1 for item in modelli_apple)
print ("\nNumero modelli tot: ",count)
# Out:
# ['Apple Iphone XR With Face Time - 64 GB'
#  'Apple Iphone XS Max With Facetime - 512 GB'
#  'Apple Iphone XS With Facetime - 512 GB'
#  'Apple iPhone 11 Pro Max Dual SIM with FaceTime - 64GB'
#  'Apple iPhone 11 Pro Max with FaceTime - 512GB'
#  'Apple iPhone 11 Pro with FaceTime - 256GB'
#  'Apple iPhone 11 Pro with FaceTime - 512GB'
#  'Apple iPhone 11 with FaceTime - 256GB'
#  'Apple iPhone 7 Plus with FaceTime - 128GB'
#  'Apple iPhone 7 Plus with FaceTime - 256GB'
#  'Apple iPhone 8 Plus without FaceTime - 64GB'
#  'Apple iPhone XR without Face Time - 64GB'
#  'Apple iPhone Xs Max Dual SIM With FaceTime - 64GB'
#  'Apple iPhone Xs Max Without FaceTime - 512GB'
#  'Apple iPhone Xs Without FaceTime - 256GB'
#  'Apple iPhone Xs Without FaceTime - 64GB']
#
# Numero modelli tot:  16

# %%
# modelli samsung
modelli_samsung = samsung ["name"].unique()
modelli_samsung.sort()
print(modelli_samsung)
count_samsung = sum (1 for item in modelli_samsung)
print ("\nNumero modelli tot: ",count_samsung)
# Out:
# ['Samsung Galaxy Fold Dual SIM - 512GB'
#  'Samsung Galaxy Note 10 Plus - 256GB'
#  'Samsung Galaxy S10 Plus Dual Sim - 1Tb'
#  'Samsung Galaxy S20 Plus Dual SIM - 128GB'
#  'Samsung Galaxy S20 Ultra Dual SIM - 128GB'
#  'Samsung Galaxy Z Flip Dual SIM - 256GB']
#
# Numero modelli tot:  6

# %%
# modelli huawei
modelli_huawei = huawei ["name"].unique()
modelli_huawei.sort()
print(modelli_huawei)
count_huawei = sum (1 for item in modelli_huawei)
print ("\nNumero modelli tot: ",count_huawei)
# Out:
# ['Huawei Mate 20 Pro Dual Sim - 128 GB'
#  'Huawei Mate 9 Porsche Design Dual Sim - 256GB'
#  'Huawei Mate RS Porsche Design Dual SIM - 256GB'
#  'Huawei P40 Pro Single SIM and E-SIM - 256GB'
#  'Porsche design Huawei Mate 20 RS Dual SIM - 512GB']
#
# Numero modelli tot:  5

# %%
# modelli colore nero

color_black = mobile [mobile["Color"]== "Black"]
color_black
# Out:
#       Unnamed: 0                                            name Generation  \
# 3              3            Samsung Galaxy Fold Dual SIM - 512GB     4G LTE
# 10            10   Huawei Mate 9 Porsche Design Dual Sim - 256GB     4G LTE
# 24            24  Huawei Mate RS Porsche Design Dual SIM - 256GB     4G LTE
# 33            33                                Cat S61 Dual Sim       64GB
# 38            38                  Sony Xperia 1 Dual SIM - 128GB     4G LTE
# ...          ...                                             ...        ...
# 2710        2710   Huawei Mate 9 Porsche Design Dual Sim - 256GB     4G LTE
# 2724        2724  Huawei Mate RS Porsche Design Dual SIM - 256GB     4G LTE
# 2733        2733                                Cat S61 Dual Sim       64GB
# 2738        2738                  Sony Xperia 1 Dual SIM - 128GB     4G LTE
# 2745        2745           Apple iPhone 11 with FaceTime - 256GB     4G LTE
#
# ...
