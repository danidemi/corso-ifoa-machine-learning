# %%
import pandas as pd

# %%
udemy = pd.read_csv("C:/Users/massimomayer/corso-ifoa-machine-learning/AriasJaqueline/udemy_courses.csv")
udemy
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# **INSPECT A DATA FRAME**

# %%
price = udemy ["price"]
print (price)
print ()
print (type (price))
# Out:
# 0       200
# 1        75
# 2        45
# 3        95
# 4       200
#        ...
# 3673    100
# 3674     25
# 3675     40
# 3676     50
# 3677     45
# Name: price, Length: 3678, dtype: int64
#
# <class 'pandas.core.series.Series'>

# %%
# some info on the series.
print( price.max() )
print( price.min() )
print( price.mean() )
print( price.median() )
print( price.std() )
print( price.idxmax() )
# Out:
# 200
# 0
# 66.0494834148994
# 45.0
# 61.00575547648037
# 0

# %%
# description of the series.
price.describe()
# Out:
# count    3678.000000
# mean       66.049483
# std        61.005755
# min         0.000000
# 25%        20.000000
# 50%        45.000000
# 75%        95.000000
# max       200.000000
# Name: price, dtype: float64

# %% [markdown]
# **SELECTION i.loc**

# %%
# 1st row

sel = udemy.iloc[ 0 ]
print( "row at index 0" )
print( sel )
print( type(sel) )
print( )

# 2nd row
print( "row at index 1" )
print(udemy.iloc[ 1 ])
print( )

# 3rd row
print( "row at index 2" )
print(udemy.iloc[ 2 ])
# Out:
# row at index 0
# course_id                                                        1070968
# course_title                          Ultimate Investment Banking Course
# url                    https://www.udemy.com/ultimate-investment-bank...
# is_paid                                                             True
# price                                                                200
# num_subscribers                                                     2147
# num_reviews                                                           23
# num_lectures                                                          51
# level                                                         All Levels
# content_duration                                                     1.5
# published_timestamp                                 2017-01-18T20:58:58Z
# subject                                                 Business Finance
# Name: 0, dtype: object
# <class 'pandas.core.series.Series'>
#
# row at index 1
# ...

# %% [markdown]
# **SELECTION .shape**

# %%
# last row

print(udemy.shape)
print()

print("all in one row")
print(udemy.iloc[udemy.shape[0]-1])

print("all expanded")
dimensions = udemy.shape
number_of_rows = dimensions[0]
last_index = number_of_rows - 1
last_row = udemy.iloc[ last_index ]
print( last_row )

print("but there's a easier way")
print(udemy.iloc[-1])
# Out:
# (3678, 12)
#
# all in one row
# course_id                                                         297602
# course_title           Using MODX CMS to Build Websites: A Beginner's...
# url                    https://www.udemy.com/using-modx-cms-to-build-...
# is_paid                                                             True
# price                                                                 45
# num_subscribers                                                      901
# num_reviews                                                           36
# num_lectures                                                          20
# level                                                     Beginner Level
# content_duration                                                       2
# published_timestamp                                 2014-09-28T19:51:11Z
# subject                                                  Web Development
# Name: 3677, dtype: object
# all expanded
# ...

# %%
corso_piu_venduto = udemy["subject"]
print (corso_piu_venduto)
print (price)
# Out:
# 0       Business Finance
# 1       Business Finance
# 2       Business Finance
# 3       Business Finance
# 4       Business Finance
#               ...
# 3673     Web Development
# 3674     Web Development
# 3675     Web Development
# 3676     Web Development
# 3677     Web Development
# Name: subject, Length: 3678, dtype: object
# 0       200
# 1        75
# 2        45
# 3        95
# 4       200
#        ...
# 3673    100
# 3674     25
# 3675     40
# 3676     50
# 3677     45
# Name: price, Length: 3678, dtype: int64
