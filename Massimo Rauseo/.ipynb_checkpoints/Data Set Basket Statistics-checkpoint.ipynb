# %%
import pandas as pd

# %%
Basket_statistics = pd.read_csv("players_stats_by_season_full_details.csv")
Basket_statistics
# Out:
#       League       Season           Stage                 Player Team  GP  \
# 0        NBA  2019 - 2020  Regular_Season           James Harden  HOU  68
# 1        NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66
# 2        NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70
# 3        NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63
# 4        NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60
# ...      ...          ...             ...                    ...  ...  ..
# 53793    NBA  1999 - 2000        Playoffs            John Salley  LAL  18
# 53794    NBA  1999 - 2000        Playoffs          Muggsy Bogues  TOR   3
# 53795    NBA  1999 - 2000        Playoffs        Jerome Williams  DET   3
# 53796    NBA  1999 - 2000        Playoffs       Randy Livingston  PHX   7
# 53797    NBA  1999 - 2000        Playoffs          Doug Christie  TOR   3
#
#           MIN  FGM   FGA  3PM  ...   PTS  birth_year  birth_month  \
# ...

# %%
Basket_statistics = pd.read_csv("C:/Users/Amministratore/corso-ifoa-machine-learning/Massimo Rauseo/players_stats_by_season_full_details.csv")

# %%
Basket_statistics
# Out:
#       League       Season           Stage                 Player Team  GP  \
# 0        NBA  2019 - 2020  Regular_Season           James Harden  HOU  68
# 1        NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66
# 2        NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70
# 3        NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63
# 4        NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60
# ...      ...          ...             ...                    ...  ...  ..
# 53793    NBA  1999 - 2000        Playoffs            John Salley  LAL  18
# 53794    NBA  1999 - 2000        Playoffs          Muggsy Bogues  TOR   3
# 53795    NBA  1999 - 2000        Playoffs        Jerome Williams  DET   3
# 53796    NBA  1999 - 2000        Playoffs       Randy Livingston  PHX   7
# 53797    NBA  1999 - 2000        Playoffs          Doug Christie  TOR   3
#
#           MIN  FGM   FGA  3PM  ...   PTS  birth_year  birth_month  \
# ...

# %% [markdown]
# Giocatore con maggior numero di punti rispetto ai minuti giocati

# %%
Basket_statistics.describe
# Out:
# <bound method NDFrame.describe of       League       Season           Stage                 Player Team  GP  \
# 0        NBA  2019 - 2020  Regular_Season           James Harden  HOU  68
# 1        NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66
# 2        NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70
# 3        NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63
# 4        NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60
# ...      ...          ...             ...                    ...  ...  ..
# 53793    NBA  1999 - 2000        Playoffs            John Salley  LAL  18
# 53794    NBA  1999 - 2000        Playoffs          Muggsy Bogues  TOR   3
# 53795    NBA  1999 - 2000        Playoffs        Jerome Williams  DET   3
# 53796    NBA  1999 - 2000        Playoffs       Randy Livingston  PHX   7
# 53797    NBA  1999 - 2000        Playoffs          Doug Christie  TOR   3
#
# ...

# %%
for i in Basket_statistics["Player"].unique():
    print(i)
# Out:
# James Harden
# Damian Lillard
# Devin Booker
# Giannis Antetokounmpo
# Trae Young
# Luka Doncic
# Bradley Beal
# LeBron James
# Donovan Mitchell
# Anthony Davis
# C.J. McCollum
# Russell Westbrook
# Jayson Tatum
# Kawhi Leonard
# Zach LaVine
# DeMar DeRozan
# Brandon Ingram
# Nikola Jokic
# Tobias Harris
# Buddy Hield
# Pascal Siakam
# Collin Sexton
# Shai Gilgeous-Alexander
# T.J. Warren
# Spencer Dinwiddie
# Khris Middleton
# Bojan Bogdanovic
# Julius Randle
# Chris Paul
# Dennis Schroder
# Evan Fournier
# Nikola Vucevic
# Ja Morant
# Lou Williams
# Dillon Brooks
# Andrew Wiggins
# Joel Embiid
# Montrezl Harrell
# Jrue Holiday
# Kristaps Porzingis
# Danilo Gallinari
# Jaylen Brown
# Jimmy Butler
# Domantas Sabonis
# Bam Adebayo
# Devonte' Graham
# Kemba Walker
# Terry Rozier
# Kyle Lowry
# Tim Hardaway Jr.
# Jamal Murray
# Jordan Clarkson
# De'Aaron Fox
# Harrison Barnes
# Kelly Oubre, Jr.
# Jonas Valanciunas
# Hassan Whiteside
# Marcus Morris
# Rudy Gobert
# Kendrick Nunn
# ...

# %%
Basket_statistics[min]
# Out:
# 0        843
# 1        674
# 2        398
# 3        293
# 4        568
#         ...
# 53793      0
# 53794      9
# 53795      0
# 53796      6
# 53797      8
# Name: 3PA, Length: 53798, dtype: int64

# %%
Basket_statistics["PTS"]
# Out:
# 0        2335
# 1        1978
# 2        1863
# 3        1857
# 4        1778
#          ...
# 53793      17
# 53794      16
# 53795      15
# 53796      14
# 53797      12
# Name: PTS, Length: 53798, dtype: int64
