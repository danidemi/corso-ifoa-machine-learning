# %%
import pandas as pd

# %%
df1=pd.read_csv("C:\\Users\\giuli\\reported.csv")
df1
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 0   1950          2784               2306            120       1      105
# 1   1951          3284               2754            125       1      109
# 2   1952          3160               2608            119       1      104
# 3   1953          2909               2689            119       1      105
# 4   1954          3028               2791            126       1      107
# ..   ...           ...                ...            ...     ...      ...
# 61  2011         14988              12267           1005       2      947
# 62  2012         14734              12148            974       2      914
# 63  2013         14603              12072            896       3      837
# 64  2014         14890              12305            923       3      859
# 65  2015         15342              12803            932       3      868
#
#     sexual.offenses  rape  stealing.general  burglary  ...  vehicle.theft  \
# ...

# %% [markdown]
# esplorazione datframe

# %%
df1.info
# Out:
# <bound method DataFrame.info of     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 0   1950          2784               2306            120       1      105
# 1   1951          3284               2754            125       1      109
# 2   1952          3160               2608            119       1      104
# 3   1953          2909               2689            119       1      105
# 4   1954          3028               2791            126       1      107
# ..   ...           ...                ...            ...     ...      ...
# 61  2011         14988              12267           1005       2      947
# 62  2012         14734              12148            974       2      914
# 63  2013         14603              12072            896       3      837
# 64  2014         14890              12305            923       3      859
# 65  2015         15342              12803            932       3      868
#
# ...

# %% [markdown]
# prova condizione

# %%
print(df1['assault'])
# Out:
# 0     105
# 1     109
# 2     104
# 3     105
# 4     107
#      ...
# 61    947
# 62    914
# 63    837
# 64    859
# 65    868
# Name: assault, Length: 66, dtype: int64

# %%
higth_assault=(df1[df1.assault>900])
higth_assault
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 58  2008         14938              12433            968       2      918
# 59  2009         15101              12588            980       2      927
# 60  2010         14605              12003            991       4      936
# 61  2011         14988              12267           1005       2      947
# 62  2012         14734              12148            974       2      914
#
#     sexual.offenses  rape  stealing.general  burglary  ...  vehicle.theft  \
# 58              154    59              6091      1023  ...          304.0
# 59              169    64              5947      1026  ...          255.0
# 60              183    64              5631       985  ...          227.0
# 61              181    69              5783       995  ...          213.0
# 62              178    66              5613       922  ...          169.0
#
#     out.of.vehicle.theft  shop.theft  robbery  fraud  criminal.damage  \
# ...

# %% [markdown]
# doppia condizione

# %%
higth_assault=higth_assault[higth_assault.murder>3]
higth_assault
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 60  2010         14605              12003            991       4      936
#
#     sexual.offenses  rape  stealing.general  burglary  ...  vehicle.theft  \
# 60              183    64              5631       985  ...          227.0
#
#     out.of.vehicle.theft  shop.theft  robbery  fraud  criminal.damage  \
# 60                 733.0       684.0       98   1115             1760
#
#     other.penal.crimes  narcotics  drunk.driving  population
# 60                2601      937.0            316     9378000
#
# [1 rows x 21 columns]

# %%
mode_murd_rate=df1['murder'].mode()
print(mode_murd_rate)
# Out:
# 0    2
# dtype: int64

# %% [markdown]
# creazione nuova colonna

# %%
df1["perc_crime_totpop"]=(df1["crimes.total"]/df1["population"])*100

df1
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 0   1950          2784               2306            120       1      105
# 1   1951          3284               2754            125       1      109
# 2   1952          3160               2608            119       1      104
# 3   1953          2909               2689            119       1      105
# 4   1954          3028               2791            126       1      107
# ..   ...           ...                ...            ...     ...      ...
# 61  2011         14988              12267           1005       2      947
# 62  2012         14734              12148            974       2      914
# 63  2013         14603              12072            896       3      837
# 64  2014         14890              12305            923       3      859
# 65  2015         15342              12803            932       3      868
#
#     sexual.offenses  rape  stealing.general  burglary  ...  shop.theft  \
# ...

# %% [markdown]
# il crimine è quasi quadruplicato dal 1950 al 2015, anche tenendo conto dell'aumento della popolazione

# %%
0.155741/0.039692
# Out:
# 3.9237377809130303

# %% [markdown]
# nuova condizione

# %%
hight_rape_rate=df1[df1["rape"]==df1["rape"].max()]
hight_rape_rate
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 61  2011         14988              12267           1005       2      947
# 64  2014         14890              12305            923       3      859
#
#     sexual.offenses  rape  stealing.general  burglary  ...  \
# 61              181    69              5783       995  ...
# 64              210    69              5572       913  ...
#
#     out.of.vehicle.theft  shop.theft  robbery  fraud  criminal.damage  \
# 61                 706.0       663.0      103   1220             1774
# 64                 542.0       505.0       86   1610             1559
#
#     other.penal.crimes  narcotics  drunk.driving  population  \
# 61                2721      946.0            314     9449000
# 64                2585      983.0            271     9747000
#
#     perc_crime_totpop
# 61           0.158620
# 64           0.152765
#
# [2 rows x 22 columns]

# %%
df1['drunk.driving'].min()
# Out:
# 49

# %%
df1['crimes.total'].median()
# Out:
# 11654.0
