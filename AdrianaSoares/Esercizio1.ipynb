# %%
import pandas as pd

# %%
skills = pd.read_csv("C:/Users/Amministratore/corso-ifoa-machine-learning/AdrianaSoares/skills.csv")
skills
# Out:
#      Unnamed: 0                                   Sofware Engineer  \
# 0             0  ['agile, AutoCAD, C++, CAD, Oral, data entry, ...
# 1             1  ['Skills Experience Total Years Last Used\nHTM...
# 2             2  ['Programming Languages: C, C++, JAVA, MySQL, ...
# 3             3  ['C#, JAVA/J2EE, C, X++, VBA\nQuery Languages:...
# 4             4  ['C/C++, Python, Java, JavaScript, MongoDB, No...
# ..          ...                                                ...
# 195         195  ['Java, JSP, JDBC\nAgile Development\nHTML and...
# 196         196  ['C/C++\nPython\nLinux Drivers\nTCP/IP\nChef/N...
# 197         197  ['Programming Languages:\nC,C++,JAVA,Visual Ba...
# 198         198  ['Linux\nJava, Spring Framework, Hibernate\nSc...
# 199         199  ['C, C++, Java, Python, HTML/CSS, JavaScript, ...
#
#                                       Graphic Designer  \
# 0    ['Customer-oriented\nEmployee training and dev...
# ...
