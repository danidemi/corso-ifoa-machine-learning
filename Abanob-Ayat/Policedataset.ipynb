# %%
import pandas as pd

# %%
police_us=pd.read_csv("C:/Users/Amministratore/Gitlearning/corso-ifoa-machine-learning/Abanob-Ayat/shootings.csv")
police_us
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
print(police_us.shape)
# Out:
# (4895, 15)

# %%
police_us.set_index(["name" , "armed"]).count(level="name")
# Out:
#                         id  date  manner_of_death  age  gender  race  city  \
# name
#  Austin Wilburly  Reid   1     1                1    1       1     1     1
# A'Donte Washington       1     1                1    1       1     1     1
# A.B. Carr                1     1                1    1       1     1     1
# Aaron Allen Przekop      1     1                1    1       1     1     1
# Aaron Bailey             1     1                1    1       1     1     1
# ...                     ..   ...              ...  ...     ...   ...   ...
# Zepp Crouchet            1     1                1    1       1     1     1
# Zhonghua Li              1     1                1    1       1     1     1
# Zoe Dowdell              1     1                1    1       1     1     1
# Zonell Williams          1     1                1    1       1     1     1
# Zyon Romeir Wyche        1     1                1    1       1     1     1
#
# ...

# %%
police_us.loc[0, :]
# Out:
# id                                   3
# name                        Tim Elliot
# date                        2015-01-02
# manner_of_death                   shot
# armed                              gun
# age                                 53
# gender                               M
# race                             Asian
# city                           Shelton
# state                               WA
# signs_of_mental_illness           True
# threat_level                    attack
# flee                       Not fleeing
# body_camera                      False
# arms_category                     Guns
# Name: 0, dtype: object

# %%
police_us.loc[[0, 1, 2,], :]
# Out:
#    id                name        date   manner_of_death    armed   age gender  \
# 0   3          Tim Elliot  2015-01-02              shot      gun  53.0      M
# 1   4    Lewis Lee Lembke  2015-01-02              shot      gun  47.0      M
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered  unarmed  23.0      M
#
#        race     city state  signs_of_mental_illness threat_level         flee  \
# 0     Asian  Shelton    WA                     True       attack  Not fleeing
# 1     White    Aloha    OR                    False       attack  Not fleeing
# 2  Hispanic  Wichita    KS                    False        other  Not fleeing
#
#    body_camera arms_category
# 0        False          Guns
# 1        False          Guns
# 2        False       Unarmed

# %%
police_us.loc[0:10, 'race':'state']
# Out:
#         race           city state
# 0      Asian        Shelton    WA
# 1      White          Aloha    OR
# 2   Hispanic        Wichita    KS
# 3      White  San Francisco    CA
# 4   Hispanic          Evans    CO
# 5      White        Guthrie    OK
# 6   Hispanic       Chandler    AZ
# 7      White        Assaria    KS
# 8      White     Burlington    IA
# 9      Black      Knoxville    PA
# 10     White       Stockton    CA

# %%
police_us[police_us.city=='San Francisco']
# Out:
#         id                     name        date manner_of_death       armed  \
# 3        8          Matthew Hoffman  2015-01-04            shot  toy weapon
# 140    182      Amilcar Perez-Lopez  2015-02-26            shot       knife
# 198    221              Alice Brown  2015-03-17            shot     unknown
# 761    922          Herbert Benitez  2015-10-15            shot         gun
# 833    998      Javier Lopez Garcia  2015-11-11            shot         gun
# 888   1052              Mario Woods  2015-12-02            shot       knife
# 1233  1443             Luis Gongora  2016-04-07            shot       knife
# 1330  1548  Jessica Nelson-Williams  2016-05-19            shot     unarmed
# 1703  1970       Nicholas McWherter  2016-10-14            shot         gun
# 2202  2556         Nicholas Flusche  2017-05-03            shot       knife
# 2248  2603                 John Eno  2017-05-23            shot         gun
# ...

# %%
police_us[police_us.city=='San Francisco'].race
# Out:
# 3          White
# 140     Hispanic
# 198        White
# 761     Hispanic
# 833     Hispanic
# 888        Black
# 1233    Hispanic
# 1330       Black
# 1703       White
# 2202       White
# 2248       White
# 2565       Black
# 2737       Black
# 2964    Hispanic
# 3010       Asian
# Name: race, dtype: object

# %%
police_us[police_us.city=='San Francisco'].state
# Out:
# 3       CA
# 140     CA
# 198     CA
# 761     CA
# 833     CA
# 888     CA
# 1233    CA
# 1330    CA
# 1703    CA
# 2202    CA
# 2248    CA
# 2565    CA
# 2737    CA
# 2964    CA
# 3010    CA
# Name: state, dtype: object

# %%
police_us.iloc[:, [0,7]]
# Out:
#         id      race
# 0        3     Asian
# 1        4     White
# 2        5  Hispanic
# 3        8     White
# 4        9  Hispanic
# ...    ...       ...
# 4890  5916     Black
# 4891  5925     Black
# 4892  5918     White
# 4893  5921     White
# 4894  5924     White
#
# [4895 rows x 2 columns]

# %%
police_us.index
# Out:
# RangeIndex(start=0, stop=4895, step=1)

# %%
police_us[police_us["body_camera"]=='False']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'body_camera'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-78c53340f395> in <module>
# ...

# %%
police_us["body_camera"]==False
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'body_camera'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-d3ebc9f58aa8> in <module>
# ----> 1 police_us["body_camera"]==False
#
# ...

# %%
police_us.index
# Out:
# RangeIndex(start=0, stop=4895, step=1)

# %%
police_us.body_camera.value_counts()["False"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-e660e06ad75a> in <module>
# ----> 1 police_us.body_camera.value_counts()["False"]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'body_camera'
